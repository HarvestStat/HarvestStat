# %% [markdown]
# # HarvestStat Data Profiling - Niger

# %%
import glob, json
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import requests
import numpy as np
import pandas as pd
import geopandas as gpd
from tools import save_npz, PrintAdminUnits, PlotAdminShapes
from tools import FDW_PD_Sweeper, FDW_PD_AvalTable, FDW_PD_Compiling, FDW_PD_ValidateFnidName
from tools import FDW_PD_CreateAdminLink, FDW_PD_RatioAdminLink, FDW_PD_ConnectAdminLink
from tools import FDW_PD_CaliSeasonYear
from tools_graphic import PlotBarProduction, PlotLinePAY
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None

# %%
# Load FEWS NET administrative boundaries ------- #
epsg = 'EPSG:32631' # Niger
fn_shapes = sorted(glob.glob('../data/shapefile/fewsnet/NE_Admin?_????.shp'))
shape_all = []
for fn in fn_shapes:
    name = fn[-18:-4]
    exec('%s = gpd.read_file("%s").to_crs("%s")' % (name, fn, epsg))
    exec('%s["area"] = %s["geometry"].area/10**6' % (name, name))
    exec('shape_all.append(%s)' % (name))
shape_all = pd.concat(shape_all, axis=0).reset_index(drop=True)
PrintAdminUnits(shape_all)
# ----------------------------------------------- #

# FDW API host address -------------------------- #
host = 'https://fdw.fews.net'
#read in username and password
auth = tuple(json.loads(open('token.json', "r").read()))
parameters = {
    'format': 'json',
    'country': 'Niger',
    'product': ['R011','R012','R013','R014','R015','R017','R018'],
    'survey_type': 'crop:best'
}
endpoint = '/api/cropproductionindicatorvalue/'
response = requests.get(host + endpoint, auth=auth, params=parameters, proxies={})
response.raise_for_status()
df = pd.DataFrame.from_records(response.json())
# ----------------------------------------------- #

###################################################
# The current submitted data has an issue on start_date. Here we manually correct it.
idx = df['start_date'].apply(lambda x: x[-5:]) == '10-01'
df.loc[idx, 'start_date'] = df.loc[idx, 'start_date'].apply(lambda x: x[:-5] + '12-01')
###################################################
# Out:
# - FEWS NET admin shapefiles ------------------- #
# | year	 | Admin1   | # units   | Admin2   | # units   | Admin3   | # units   |
# | 1972	 | NE1972A1 | 7	| NE1972A2	| 35	| nan	| 0	|
# | 1992	 | NE1992A1 | 8	| NE1992A2	| 36	| nan	| 0	|
# | 2001	 | NE2001A1 | 8	| NE2001A2	| 37	| nan	| 0	|
# | 2012	 | NE2012A1 | 8	| NE2012A2	| 74	| nan	| 0	|
# | 2018	 | NE2018A1 | 8	| NE2018A2	| 67	| nan	| 0	|
# ----------------------------------------------- #

# %%
# Shape file correction
# Correct the 2012 admin file for Nigeria to include Agadez Commune
NE_Admin2_2012.loc[NE_Admin2_2012.FNID=='NE2012A20109','ADMIN2'] = 'Agadez Commune'
NE_Admin2_2012.loc[NE_Admin2_2012.FNID=='NE2012A20109','ADMIN2FR'] = 'Agadez Commune'
NE_Admin2_2012.loc[NE_Admin2_2012.FNID=='NE2012A20109','ALIASES'] = 'None'

# Manual Pre-processing before Sweeping --------- #
# 1. Default setting 
# a) None-type crop production system
df.loc[df['crop_production_system'].isna(), 'crop_production_system'] = 'none'
df.loc[df['crop_production_system'] == '', 'crop_production_system'] = 'none'
# b) None-type population group
df.loc[df['population_group'].isna(), 'population_group'] = 'none'
df.loc[df['population_group'] == '', 'population_group'] = 'none'
# 2. Manual correction
# a) Season name
df.loc[df['season_name'] == 'Main season', 'season_name'] = 'Main'
# b) order of magnitude error in Agadaz commune right after it was creted
df.loc[(df.fnid=='NE2012A20109')&(pd.to_datetime(df.season_date).dt.year==2013)&(df.indicator=='Area Planted'),'value'] = \
df.loc[(df.fnid=='NE2012A20109')&(pd.to_datetime(df.season_date).dt.year==2013)&(df.indicator=='Area Planted'),'value']/10
df.loc[(df.fnid=='NE2012A20109')&(pd.to_datetime(df.season_date).dt.year==2013)&(df.indicator=='Quantity Produced'),'value'] = \
df.loc[(df.fnid=='NE2012A20109')&(pd.to_datetime(df.season_date).dt.year==2013)&(df.indicator=='Quantity Produced'),'value']/10

# FDW Production Data Inspection ---------------- #
df, df_raw = FDW_PD_Sweeper(df)
table_dict = FDW_PD_AvalTable(df, shape_all)
# ----------------------------------------------- #

# FEWS NET Shapefile comparison ----------------- #
shape_used = pd.concat([NE_Admin2_1972,NE_Admin2_1992,NE_Admin2_2001,NE_Admin2_2012,NE_Admin2_2018], axis=0)
PlotAdminShapes(shape_used, label=True)
# ----------------------------------------------- #
# Out:
# - Remove missing records ---------------------- #
# Orignial data points: 26,980
# Removed 2,394 "Missing Value" points
# 8,260/8,348 "Area Planted" points are retained.
# 8,163/8,348 "Quantity Produced" points are retained.
# 8,163/8,348 "Yield" points are retained.
# 0/1,936 "Area Harvested" points are retained.
# Current data points: 24,586
#
# - Minor changes are applied ------------------- #
#
# - Basic information --------------------------- #
# Data period: 1980 - 2021
# 15 grain types are found: Bambara groundnut, Cassava, Cowpeas (Mixed), Fonio, Groundnuts (In Shell), Maize (Corn), Millet, Okras (Fresh), Onions, Rice (Paddy), Sesame Seed, Sorghum, Sorrel, Tigernut, Tomato
# 1 seasons are found: Main (06-01)
# 1 crop production system are found: none
# Data sources include:
# [1] Ministere de l'Agriculture, Niger --- FEWS NET Agro Maps, Niger
# [2] Ministere de l'Agriculture, Niger --- Official agricultural statistics, Niger
# [3] Ministere de l'Agriculture, Niger --- Resultats definitifs campagne agricole, Niger
# Administrative-1 fnids: 0
# Administrative-2 fnids: 175
# 0 reporting units are found:
#
# - Total production over time ------------------ #
# season_name             Main
#
# Bambara groundnut       0.3%
# Cassava                 0.0%
# Cowpeas (Mixed)        18.8%
# Fonio                   0.0%
# Groundnuts (In Shell)   4.0%
# Maize (Corn)            0.1%
# Millet                 55.8%
# Okras (Fresh)           0.2%
# Onions                  0.2%
# Rice (Paddy)            0.4%
# Sesame Seed             0.5%
# Sorghum                19.0%
# Sorrel                  0.4%
# Tigernut                0.2%
# Tomato                  0.0%
#
# - Crop calendar ------------------------------- #
#                   product season_name planting_month harvest_month
# 0       Bambara groundnut        Main          06-01         12-01
# 1                 Cassava        Main          06-01         12-01
# 2         Cowpeas (Mixed)        Main          06-01         12-01
# 3                   Fonio        Main          06-01         12-01
# 4   Groundnuts (In Shell)        Main          06-01         12-01
# 5            Maize (Corn)        Main          06-01         12-01
# 6                  Millet        Main          06-01         12-01
# 7           Okras (Fresh)        Main          06-01         12-01
# 8                  Onions        Main          06-01         12-01
# 9            Rice (Paddy)        Main          06-01         12-01
# 10            Sesame Seed        Main          06-01         12-01
# 11                Sorghum        Main          06-01         12-01
# 12                 Sorrel        Main          06-01         12-01
# 13               Tigernut        Main          06-01         12-01
# 14                 Tomato        Main          06-01         12-01
#
# - Recorded years per season ------------------- #
# Main: 42 years (1980-2021) (missing: 2 years)
#
# - Number of "Quantity Produced" data points --- #
# NE1972A2: 1,248 data points are found.
# NE1992A2: 1,333 data points are found.
# NE2001A2: 2,016 data points are found.
# NE2012A2: 3,566 data points are found.
#
# - Districts with population group(s) ---------- #
# 0 districts includes 'population_group'.
#
# Table of available data
# ----------------------------------------------- #
# Crop type: Bambara groundnut
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             1992A2 2001A2 2012A2
# year
# 1992                     1/36    NaN    NaN
# 1993                      NaN    NaN    NaN
# 1994                      NaN    NaN    NaN
# 1995                      NaN    NaN    NaN
# 1996                      NaN    NaN    NaN
# 1997                      NaN    NaN    NaN
# 1998                      NaN    NaN    NaN
# 1999                      NaN    NaN    NaN
# 2000                      NaN    NaN    NaN
# 2001                    11/36    NaN    NaN
# 2002                      NaN  13/37    NaN
# 2003                      NaN  12/37    NaN
# 2004                      NaN   9/37    NaN
# 2005                      NaN  13/37    NaN
# 2006                      NaN  17/37    NaN
# 2007                      NaN  18/37    NaN
# 2008                      NaN  12/37    NaN
# 2009                      NaN  15/37    NaN
# 2010                      NaN  19/37    NaN
# 2011                      NaN  20/37    NaN
# 2012                      NaN    NaN  39/74
# 2013                      NaN    NaN  37/74
# 2014                      NaN    NaN  38/74
# 2015                      NaN    NaN  45/74
# 2016                      NaN    NaN  41/74
# 2017                      NaN    NaN    NaN
# 2018                      NaN    NaN    NaN
# 2019                      NaN    NaN  39/74
# 2020                      NaN    NaN  39/74
# 2021                      NaN    NaN  36/74
# ----------------------------------------------- #
# Crop type: Cassava
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             2001A2 2012A2
# year
# 2006                     1/37    NaN
# 2007                     1/37    NaN
# 2008                     1/37    NaN
# 2009                      NaN    NaN
# 2010                     1/37    NaN
# 2011                      NaN    NaN
# 2012                      NaN   1/74
# 2013                      NaN   1/74
# 2014                      NaN   1/74
# 2015                      NaN   1/74
# 2016                      NaN   2/74
# ----------------------------------------------- #
# Crop type: Cowpeas (Mixed)
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             1972A2 1992A2 2001A2 2012A2
# year
# 1982                    27/35    NaN    NaN    NaN
# 1983                    30/35    NaN    NaN    NaN
# 1984                    30/35    NaN    NaN    NaN
# 1985                    30/35    NaN    NaN    NaN
# 1986                    33/35    NaN    NaN    NaN
# 1987                    32/35    NaN    NaN    NaN
# 1988                    32/35    NaN    NaN    NaN
# 1989                    33/35    NaN    NaN    NaN
# 1990                    29/35    NaN    NaN    NaN
# 1991                    31/35    NaN    NaN    NaN
# 1992                      NaN  32/36    NaN    NaN
# 1993                      NaN  30/36    NaN    NaN
# 1994                      NaN  31/36    NaN    NaN
# 1995                      NaN  31/36    NaN    NaN
# 1996                      NaN  31/36    NaN    NaN
# 1997                      NaN  31/36    NaN    NaN
# 1998                      NaN  31/36    NaN    NaN
# 1999                      NaN  31/36    NaN    NaN
# 2000                      NaN  30/36    NaN    NaN
# 2001                      NaN  31/36    NaN    NaN
# 2002                      NaN    NaN  33/37    NaN
# 2003                      NaN    NaN  28/37    NaN
# 2004                      NaN    NaN  33/37    NaN
# 2005                      NaN    NaN  33/37    NaN
# 2006                      NaN    NaN  35/37    NaN
# 2007                      NaN    NaN  33/37    NaN
# 2008                      NaN    NaN  34/37    NaN
# 2009                      NaN    NaN  36/37    NaN
# 2010                      NaN    NaN  33/37    NaN
# 2011                      NaN    NaN  32/37    NaN
# 2012                      NaN    NaN    NaN  63/74
# 2013                      NaN    NaN    NaN  63/74
# 2014                      NaN    NaN    NaN  66/74
# 2015                      NaN    NaN    NaN  69/74
# 2016                      NaN    NaN    NaN  69/74
# 2017                      NaN    NaN    NaN    NaN
# 2018                      NaN    NaN    NaN    NaN
# 2019                      NaN    NaN    NaN  65/74
# 2020                      NaN    NaN    NaN  66/74
# 2021                      NaN    NaN    NaN  64/74
# ----------------------------------------------- #
# Crop type: Fonio
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             2001A2 2012A2
# year
# 2002                     3/37    NaN
# 2003                     2/37    NaN
# 2004                     3/37    NaN
# 2005                     1/37    NaN
# 2006                     4/37    NaN
# 2007                     3/37    NaN
# 2008                     2/37    NaN
# 2009                     1/37    NaN
# 2010                     3/37    NaN
# 2011                     2/37    NaN
# 2012                      NaN   4/74
# 2013                      NaN   4/74
# 2014                      NaN   5/74
# 2015                      NaN   5/74
# 2016                      NaN   8/74
# 2017                      NaN    NaN
# 2018                      NaN    NaN
# 2019                      NaN   7/74
# 2020                      NaN   7/74
# 2021                      NaN   6/74
# ----------------------------------------------- #
# Crop type: Groundnuts (In Shell)
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             1972A2 1992A2 2001A2 2012A2
# year
# 1990                    16/35    NaN    NaN    NaN
# 1991                    18/35    NaN    NaN    NaN
# 1992                      NaN  22/36    NaN    NaN
# 1993                      NaN  21/36    NaN    NaN
# 1994                      NaN  21/36    NaN    NaN
# 1995                      NaN  24/36    NaN    NaN
# 1996                      NaN  25/36    NaN    NaN
# 1997                      NaN  25/36    NaN    NaN
# 1998                      NaN  24/36    NaN    NaN
# 1999                      NaN  24/36    NaN    NaN
# 2000                      NaN  26/36    NaN    NaN
# 2001                      NaN  26/36    NaN    NaN
# 2002                      NaN    NaN  28/37    NaN
# 2003                      NaN    NaN  22/37    NaN
# 2004                      NaN    NaN  24/37    NaN
# 2005                      NaN    NaN  24/37    NaN
# 2006                      NaN    NaN  29/37    NaN
# 2007                      NaN    NaN  30/37    NaN
# 2008                      NaN    NaN  30/37    NaN
# 2009                      NaN    NaN  29/37    NaN
# 2010                      NaN    NaN  29/37    NaN
# 2011                      NaN    NaN  28/37    NaN
# 2012                      NaN    NaN    NaN  47/74
# 2013                      NaN    NaN    NaN  46/74
# 2014                      NaN    NaN    NaN  53/74
# 2015                      NaN    NaN    NaN  56/74
# 2016                      NaN    NaN    NaN  56/74
# 2017                      NaN    NaN    NaN    NaN
# 2018                      NaN    NaN    NaN    NaN
# 2019                      NaN    NaN    NaN  52/74
# 2020                      NaN    NaN    NaN  52/74
# 2021                      NaN    NaN    NaN  50/74
# ----------------------------------------------- #
# Crop type: Maize (Corn)
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             1972A2 1992A2 2001A2 2012A2
# year
# 1980                    11/35    NaN    NaN    NaN
# 1981                     9/35    NaN    NaN    NaN
# 1982                    11/35    NaN    NaN    NaN
# 1983                     8/35    NaN    NaN    NaN
# 1984                     6/35    NaN    NaN    NaN
# 1985                     7/35    NaN    NaN    NaN
# 1986                     6/35    NaN    NaN    NaN
# 1987                     6/35    NaN    NaN    NaN
# 1988                     6/35    NaN    NaN    NaN
# 1989                     6/35    NaN    NaN    NaN
# 1990                     5/35    NaN    NaN    NaN
# 1991                     6/35    NaN    NaN    NaN
# 1992                      NaN   4/36    NaN    NaN
# 1993                      NaN   5/36    NaN    NaN
# 1994                      NaN   8/36    NaN    NaN
# 1995                      NaN   6/36    NaN    NaN
# 1996                      NaN   7/36    NaN    NaN
# 1997                      NaN   4/36    NaN    NaN
# 1998                      NaN   3/36    NaN    NaN
# 1999                      NaN   3/36    NaN    NaN
# 2000                      NaN   2/36    NaN    NaN
# 2001                      NaN   5/36    NaN    NaN
# 2002                      NaN    NaN   6/37    NaN
# 2003                      NaN    NaN   6/37    NaN
# 2004                      NaN    NaN   6/37    NaN
# 2005                      NaN    NaN   2/37    NaN
# 2006                      NaN    NaN   8/37    NaN
# 2007                      NaN    NaN   8/37    NaN
# 2008                      NaN    NaN   8/37    NaN
# 2009                      NaN    NaN   2/37    NaN
# 2010                      NaN    NaN  11/37    NaN
# 2011                      NaN    NaN  11/37    NaN
# 2012                      NaN    NaN    NaN  16/74
# 2013                      NaN    NaN    NaN  18/74
# 2014                      NaN    NaN    NaN  21/74
# 2015                      NaN    NaN    NaN  21/74
# 2016                      NaN    NaN    NaN  31/74
# 2017                      NaN    NaN    NaN    NaN
# 2018                      NaN    NaN    NaN    NaN
# 2019                      NaN    NaN    NaN  30/74
# 2020                      NaN    NaN    NaN  30/74
# 2021                      NaN    NaN    NaN  29/74
# ----------------------------------------------- #
# Crop type: Millet
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             1972A2 1992A2 2001A2 2012A2
# year
# 1980                    33/35    NaN    NaN    NaN
# 1981                    33/35    NaN    NaN    NaN
# 1982                    33/35    NaN    NaN    NaN
# 1983                    33/35    NaN    NaN    NaN
# 1984                    31/35    NaN    NaN    NaN
# 1985                    34/35    NaN    NaN    NaN
# 1986                    34/35    NaN    NaN    NaN
# 1987                    34/35    NaN    NaN    NaN
# 1988                    34/35    NaN    NaN    NaN
# 1989                    34/35    NaN    NaN    NaN
# 1990                    32/35    NaN    NaN    NaN
# 1991                    34/35    NaN    NaN    NaN
# 1992                      NaN  34/36    NaN    NaN
# 1993                      NaN  34/36    NaN    NaN
# 1994                      NaN  33/36    NaN    NaN
# 1995                      NaN  34/36    NaN    NaN
# 1996                      NaN  34/36    NaN    NaN
# 1997                      NaN  34/36    NaN    NaN
# 1998                      NaN  32/36    NaN    NaN
# 1999                      NaN  34/36    NaN    NaN
# 2000                      NaN  33/36    NaN    NaN
# 2001                      NaN  34/36    NaN    NaN
# 2002                      NaN    NaN  34/37    NaN
# 2003                      NaN    NaN  30/37    NaN
# 2004                      NaN    NaN  35/37    NaN
# 2005                      NaN    NaN  34/37    NaN
# 2006                      NaN    NaN  35/37    NaN
# 2007                      NaN    NaN  34/37    NaN
# 2008                      NaN    NaN  34/37    NaN
# 2009                      NaN    NaN  34/37    NaN
# 2010                      NaN    NaN  34/37    NaN
# 2011                      NaN    NaN  34/37    NaN
# 2012                      NaN    NaN    NaN  64/74
# 2013                      NaN    NaN    NaN  63/74
# 2014                      NaN    NaN    NaN  67/74
# 2015                      NaN    NaN    NaN  65/74
# 2016                      NaN    NaN    NaN  68/74
# 2017                      NaN    NaN    NaN    NaN
# 2018                      NaN    NaN    NaN    NaN
# 2019                      NaN    NaN    NaN  63/74
# 2020                      NaN    NaN    NaN  64/74
# 2021                      NaN    NaN    NaN  65/74
# ----------------------------------------------- #
# Crop type: Okras (Fresh)
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             2001A2 2012A2
# year
# 2002                     6/37    NaN
# 2003                     4/37    NaN
# 2004                     5/37    NaN
# 2005                     6/37    NaN
# 2006                     8/37    NaN
# 2007                     7/37    NaN
# 2008                     9/37    NaN
# 2009                     7/37    NaN
# 2010                    12/37    NaN
# 2011                    12/37    NaN
# 2012                      NaN  22/74
# 2013                      NaN  20/74
# 2014                      NaN  23/74
# 2015                      NaN  24/74
# 2016                      NaN  21/74
# 2017                      NaN    NaN
# 2018                      NaN    NaN
# 2019                      NaN  21/74
# 2020                      NaN  21/74
# 2021                      NaN  21/74
# ----------------------------------------------- #
# Crop type: Onions
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             2001A2 2012A2
# year
# 2002                     1/37    NaN
# 2003                     1/37    NaN
# 2004                     1/37    NaN
# 2005                      NaN    NaN
# 2006                      NaN    NaN
# 2007                      NaN    NaN
# 2008                      NaN    NaN
# 2009                      NaN    NaN
# 2010                      NaN    NaN
# 2011                      NaN    NaN
# 2012                      NaN   6/74
# 2013                      NaN   6/74
# 2014                      NaN   5/74
# 2015                      NaN   6/74
# 2016                      NaN  10/74
# 2017                      NaN    NaN
# 2018                      NaN    NaN
# 2019                      NaN   7/74
# 2020                      NaN   9/74
# 2021                      NaN   9/74
# ----------------------------------------------- #
# Crop type: Rice (Paddy)
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             1972A2 1992A2 2001A2 2012A2
# year
# 1980                     6/35    NaN    NaN    NaN
# 1981                     6/35    NaN    NaN    NaN
# 1982                     6/35    NaN    NaN    NaN
# 1983                     6/35    NaN    NaN    NaN
# 1984                     6/35    NaN    NaN    NaN
# 1985                     5/35    NaN    NaN    NaN
# 1986                     6/35    NaN    NaN    NaN
# 1987                     6/35    NaN    NaN    NaN
# 1988                     3/35    NaN    NaN    NaN
# 1989                      NaN    NaN    NaN    NaN
# 1990                     5/35    NaN    NaN    NaN
# 1991                      NaN    NaN    NaN    NaN
# 1992                      NaN    NaN    NaN    NaN
# 1993                      NaN   3/36    NaN    NaN
# 1994                      NaN   3/36    NaN    NaN
# 1995                      NaN   5/36    NaN    NaN
# 1996                      NaN    NaN    NaN    NaN
# 1997                      NaN   3/36    NaN    NaN
# 1998                      NaN   3/36    NaN    NaN
# 1999                      NaN   4/36    NaN    NaN
# 2000                      NaN   3/36    NaN    NaN
# 2001                      NaN   4/36    NaN    NaN
# 2002                      NaN    NaN   4/37    NaN
# 2003                      NaN    NaN   4/37    NaN
# 2004                      NaN    NaN   5/37    NaN
# 2005                      NaN    NaN   3/37    NaN
# 2006                      NaN    NaN   7/37    NaN
# 2007                      NaN    NaN   6/37    NaN
# 2008                      NaN    NaN   4/37    NaN
# 2009                      NaN    NaN   5/37    NaN
# 2010                      NaN    NaN   5/37    NaN
# 2011                      NaN    NaN   8/37    NaN
# 2012                      NaN    NaN    NaN   6/74
# 2013                      NaN    NaN    NaN   8/74
# 2014                      NaN    NaN    NaN   9/74
# 2015                      NaN    NaN    NaN   8/74
# 2016                      NaN    NaN    NaN   9/74
# 2017                      NaN    NaN    NaN    NaN
# 2018                      NaN    NaN    NaN    NaN
# 2019                      NaN    NaN    NaN   9/74
# 2020                      NaN    NaN    NaN   9/74
# 2021                      NaN    NaN    NaN   9/74
# ----------------------------------------------- #
# Crop type: Sesame Seed
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             1992A2 2001A2 2012A2
# year
# 1996                    14/36    NaN    NaN
# 1997                    15/36    NaN    NaN
# 1998                    15/36    NaN    NaN
# 1999                    15/36    NaN    NaN
# 2000                    11/36    NaN    NaN
# 2001                    12/36    NaN    NaN
# 2002                      NaN  15/37    NaN
# 2003                      NaN  15/37    NaN
# 2004                      NaN  16/37    NaN
# 2005                      NaN  21/37    NaN
# 2006                      NaN  22/37    NaN
# 2007                      NaN  23/37    NaN
# 2008                      NaN  15/37    NaN
# 2009                      NaN  20/37    NaN
# 2010                      NaN  22/37    NaN
# 2011                      NaN  22/37    NaN
# 2012                      NaN    NaN  39/74
# 2013                      NaN    NaN  39/74
# 2014                      NaN    NaN  41/74
# 2015                      NaN    NaN  40/74
# 2016                      NaN    NaN  41/74
# 2017                      NaN    NaN    NaN
# 2018                      NaN    NaN    NaN
# 2019                      NaN    NaN  39/74
# 2020                      NaN    NaN  39/74
# 2021                      NaN    NaN  37/74
# ----------------------------------------------- #
# Crop type: Sorghum
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             1972A2 1992A2 2001A2 2012A2
# year
# 1980                    32/35    NaN    NaN    NaN
# 1981                    32/35    NaN    NaN    NaN
# 1982                    32/35    NaN    NaN    NaN
# 1983                    32/35    NaN    NaN    NaN
# 1984                    29/35    NaN    NaN    NaN
# 1985                    30/35    NaN    NaN    NaN
# 1986                    32/35    NaN    NaN    NaN
# 1987                    33/35    NaN    NaN    NaN
# 1988                    32/35    NaN    NaN    NaN
# 1989                    33/35    NaN    NaN    NaN
# 1990                    30/35    NaN    NaN    NaN
# 1991                    32/35    NaN    NaN    NaN
# 1992                      NaN  32/36    NaN    NaN
# 1993                      NaN  32/36    NaN    NaN
# 1994                      NaN  32/36    NaN    NaN
# 1995                      NaN  32/36    NaN    NaN
# 1996                      NaN  32/36    NaN    NaN
# 1997                      NaN  32/36    NaN    NaN
# 1998                      NaN  32/36    NaN    NaN
# 1999                      NaN  32/36    NaN    NaN
# 2000                      NaN  31/36    NaN    NaN
# 2001                      NaN  31/36    NaN    NaN
# 2002                      NaN    NaN  33/37    NaN
# 2003                      NaN    NaN  28/37    NaN
# 2004                      NaN    NaN  34/37    NaN
# 2005                      NaN    NaN  33/37    NaN
# 2006                      NaN    NaN  34/37    NaN
# 2007                      NaN    NaN  34/37    NaN
# 2008                      NaN    NaN  34/37    NaN
# 2009                      NaN    NaN  34/37    NaN
# 2010                      NaN    NaN  33/37    NaN
# 2011                      NaN    NaN  34/37    NaN
# 2012                      NaN    NaN    NaN  64/74
# 2013                      NaN    NaN    NaN  65/74
# 2014                      NaN    NaN    NaN  67/74
# 2015                      NaN    NaN    NaN  64/74
# 2016                      NaN    NaN    NaN  68/74
# 2017                      NaN    NaN    NaN    NaN
# 2018                      NaN    NaN    NaN    NaN
# 2019                      NaN    NaN    NaN  64/74
# 2020                      NaN    NaN    NaN  65/74
# 2021                      NaN    NaN    NaN  65/74
# ----------------------------------------------- #
# Crop type: Sorrel
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             2001A2 2012A2
# year
# 2002                    14/37    NaN
# 2003                    11/37    NaN
# 2004                    13/37    NaN
# 2005                    13/37    NaN
# 2006                    18/37    NaN
# 2007                    16/37    NaN
# 2008                    16/37    NaN
# 2009                    22/37    NaN
# 2010                    22/37    NaN
# 2011                    23/37    NaN
# 2012                      NaN  38/74
# 2013                      NaN  30/74
# 2014                      NaN  38/74
# 2015                      NaN  39/74
# 2016                      NaN  49/74
# 2017                      NaN    NaN
# 2018                      NaN    NaN
# 2019                      NaN  42/74
# 2020                      NaN  48/74
# 2021                      NaN  45/74
# ----------------------------------------------- #
# Crop type: Tigernut
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             2001A2 2012A2
# year
# 2002                     4/37    NaN
# 2003                     4/37    NaN
# 2004                     6/37    NaN
# 2005                     4/37    NaN
# 2006                     5/37    NaN
# 2007                     7/37    NaN
# 2008                     3/37    NaN
# 2009                     5/37    NaN
# 2010                     1/37    NaN
# 2011                     2/37    NaN
# 2012                      NaN   8/74
# 2013                      NaN   8/74
# 2014                      NaN   8/74
# 2015                      NaN   8/74
# 2016                      NaN   8/74
# 2017                      NaN    NaN
# 2018                      NaN    NaN
# 2019                      NaN   8/74
# 2020                      NaN   8/74
# 2021                      NaN   6/74
# ----------------------------------------------- #
# Crop type: Tomato
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             2012A2
# year
# 2012                     5/74
# 2013                     6/74
# 2014                      NaN
# 2015                     6/74
# 2016                     6/74
# 2017                      NaN
# 2018                      NaN
# 2019                     4/74
# 2020                     6/74
# 2021                     6/74
# ----------------------------------------------- #
# ../figures/NE_admin_shapes.png is saved.

# %% [markdown]
# ## Niger
# Niger crop seasonal calendar
#
# ![FEWS NET](https://fews.net/sites/default/files/styles/large_width_880/public/2023-03/seasonal-calendar-niger.png?itok=UBgvvRXP)
#
# ![USDA](https://ipad.fas.usda.gov/rssiws/al/crop_calendar/images/wafrica_ng_calendar.png)
#
# - comparison of boundaries
#
# <img src="../figures/NE_admin_shapes.png"  width="60%">
#
# - In Niger, basd on the FEWS NET data, there were four times of changes in administrative units: 1972, 1992, 2012, and 2018.
#
# | year	 | Admin1   | # units   | Admin2   | # units   |
# | :---: | :----:  | :----:   | :----:   | :---:  |
# | 1972	 | NE1972A1 | 7	| NE1972A2	| 35	|
# | 1992	 | NE1992A1 | 8	| NE1992A2	| 36	|
# | 2001	 | NE2001A1 | 8	| NE2001A2	| 37	|
# | 2012	 | NE2012A1 | 8	| NE2012A2	| 74	|
# | 2018	 | NE2018A1 | 8	| NE2018A2	| 67	|
#
# - The data is all reported in a single main season
# - While there is a shapefile for 2018, there is no crop data associated with the 2018 shapefile, so we use 2012 as the most recent shapefile

# %%
# Define the latest shapefile ------------------- #
latest_level = 2
shape_latest = NE_Admin2_2012.copy().to_crs('epsg:32631')
# ----------------------------------------------- #

# Validation of FNIDs and Names ----------------- #
df = FDW_PD_ValidateFnidName(df, shape_used, shape_latest)
# ----------------------------------------------- #

# FDW Production Data Compiling ----------------- #
area, prod = FDW_PD_Compiling(df, shape_used)
area_all, prod_all = area.copy(), prod.copy()
mdx_pss = area.columns.droplevel([0,1]).unique()
# ----------------------------------------------- #
# Out:
# NE2001A20704:	"Matameye" (FDW) is changed to "Kantche" (shapefile).
# NE2012A20311:	"Dioundiou" (FDW) is changed to "Dioudiou" (shapefile).

# %%
# Link admin boundaries ------------------------- #
link_2001, over_2001 = FDW_PD_CreateAdminLink(NE_Admin2_2001, NE_Admin2_2012, 'ADMIN2', 'ADMIN2', prod, epsg)
#assert all(np.unique([v['method'] for k,v in link_2001.items()]) == 'PBR')
link_1992, over_1992 = FDW_PD_CreateAdminLink(NE_Admin2_1992, NE_Admin2_2012, 'ADMIN2', 'ADMIN2', prod, epsg)
#assert all(np.unique([v['method'] for k,v in link_1992.items()]) == 'PBR')
link_1972, over_1972 = FDW_PD_CreateAdminLink(NE_Admin2_1972, NE_Admin2_2012, 'ADMIN2', 'ADMIN2', prod, epsg)
#assert all(np.unique([v['method'] for k,v in link_1972.items()]) == 'PBR')


# Crop specific ratios
link_ratio_1972 = FDW_PD_RatioAdminLink(link_1972, prod, over_1972, mdx_pss)
link_ratio_1992 = FDW_PD_RatioAdminLink(link_1992, prod, over_1992, mdx_pss)
link_ratio_2001 = FDW_PD_RatioAdminLink(link_2001, prod, over_2001, mdx_pss)

# Merge link_ratio
assert link_ratio_1992.keys() == link_ratio_2001.keys()
assert link_ratio_1972.keys() == link_ratio_2001.keys()

link_merged = [link_ratio_1972, link_ratio_1992, link_ratio_2001]
fnids_new = list(link_merged[0].keys())
link_ratio = dict()
for fnid in fnids_new:
    container = []
    for link in link_merged:
        container.append(link[fnid])
    link_ratio[fnid] = pd.concat(container, axis=1)
# Add current unit to link_ratio
for fnid_new in link_ratio.keys():
    link_ratio[fnid_new][fnid_new] = 1.0
    link_ratio[fnid_new] = link_ratio[fnid_new].sort_index(axis=1, ascending=False)
# Connect data with AdminLink
area_new, prod_new = FDW_PD_ConnectAdminLink(link_ratio, area, prod, validation=True)
# ----------------------------------------------- #
# Out:
# CBR is considered for 'NE2001A20103' as no record found in: ['NE2012A20103']
# CBR is considered for 'NE2001A20203' as no record found in: ['NE2012A20209']
# CBR is considered for 'NE2001A20702' as no record found in: ['NE2012A20707']
# CBR is considered for 'NE1992A20103' as no record found in: ['NE2012A20103']
# CBR is considered for 'NE1992A20203' as no record found in: ['NE2012A20209']
# CBR is considered for 'NE1992A20702' as no record found in: ['NE2012A20707']
# CBR is considered for 'NE1972A20702' as no record found in: ['NE2012A20707']
# CBR is considered for 'NE1972A20203' as no record found in: ['NE2012A20209']
# CBR is considered for 'NE1972A20103' as no record found in: ['NE2012A20103']

# %%
# Manual correction ----------------------------- #
crop_new = prod_new/area_new
#I need to be able to look at the source docs here. I think maize planted area was used
#area_new.loc[2019,pd.IndexSlice['NE2012A20804',:,'Millet','Main season',:,:,'none']] = 2000
#area_new.loc[2019,pd.IndexSlice['NE2012A20805',:,'Millet','Main season',:,:,'none']] = 4000

# Complete long format DataFrame ---------------- #
df_area = area_new.T.stack().rename('value').reset_index()
df_area['indicator'] = 'area'
df_prod = prod_new.T.stack().rename('value').reset_index()
df_prod['indicator'] = 'production'
df_yield = (prod_new/area_new).T.stack().rename('value').reset_index()
df_yield['indicator'] = 'yield'
stack = pd.concat([df_area, df_prod, df_yield], axis=0)
# Add "planting year"
cols = ['season_name','product','crop_production_system','planting_month','harvest_year','harvest_month','planting_year']
season_table = df[cols].drop_duplicates()
stack = stack.merge(season_table, on=cols[:-1])
# Add country and admin names
stack = stack.merge(df[['fnid','country','country_code','admin_1','admin_2']].drop_duplicates(), on='fnid', how='inner')
names = [
    'fnid','country','country_code','admin_1','admin_2','name',
    'product','season_name','planting_year','planting_month','harvest_year','harvest_month',
    'crop_production_system','indicator','value'
]
stack = stack[names]
# ----------------------------------------------- #

# Final Processing ------------------------------ #
# Manual change of product name
product_category_custom = {
    'Bambara groundnut': 'Bambara groundnut',
    'Cassava': 'Cassava',
    'Cowpeas (Mixed)': 'Cowpeas',
    'Fonio': 'Fonio',
    'Groundnuts (In Shell)': 'Groundnuts (In Shell)',
    'Maize (Corn)': 'Maize',
    'Millet': 'Millet',
    'Okras (Fresh)': 'Okras',
    'Onions': 'Onions',
    'Rice (Paddy)': 'Rice',
    'Sesame Seed': 'Sesame Seed',
    'Sorghum': 'Sorghum',
    'Sorrel': 'Sorrel',
    'Tigernut': 'Tigernut',
    'Tomato': 'Tomato'
}
stack['product'] = stack['product'].replace(product_category_custom)
for f, r in link_ratio.items():
    mdx = pd.MultiIndex.from_frame(r.index.to_frame().reset_index(drop=True).replace(product_category_custom))
    r.index = mdx
    link_ratio[f] = r
# Calibration of crop calendar using External Crop Calendar (ECC)
ecc = pd.read_csv('../data/crop_calendar/external_crop_calendar.csv')
ecc = ecc[ecc['country'] == 'Niger']
stack, link_ratio = FDW_PD_CaliSeasonYear(stack, ecc, link_ratio)
# None admin names
stack.loc[stack['admin_1'].isna(), 'admin_1'] = 'none'
stack.loc[stack['admin_2'].isna(), 'admin_2'] = 'none'
# ----------------------------------------------- #

# Save data
fn_out = '../data/crop/adm_crop_production_NE.csv'
stack.to_csv(fn_out); print(f'{fn_out} is saved.')
save_npz('../data/crop/adm_crop_production_NE_ratio.npz', link_ratio)
# Out:
# All [season_name, product, crop_production_system] are in the external crop calendar.
# ../data/crop/adm_crop_production_NE.csv is saved.
# ../data/crop/adm_crop_production_NE_ratio.npz is saved.

# %% [markdown]
# ## Visualization of production data

# %%
# Bar chart of national crop production
country_iso, country_name = 'NE', 'Niger'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_order = ['Maize', 'Fonio','Millet', 'Rice','Sorghum']
for season_name in ['Main']:
    footnote = 'National crop production in %s - %s' % (country_name, season_name)
    fn_save = '../figures/%s_bar_natgrainprod_%s.png' % (country_iso, season_name)
    sub = df[df['season_name'] == season_name]
    fig = PlotBarProduction(sub, year, product_order, footnote, fn_save)
    fig.show()
# Out:
# ../figures/NE_bar_natgrainprod_Main.png is saved.

# %%
# Lineplot of Production-Area-Yield time-series
country_iso, country_name = 'NE', 'Niger'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_season = [
    ['Millet','Main'],
    ['Sorghum','Main'],
    ['Maize','Main'],
    ['Rice','Main'],
    ['Fonio','Main'],
]
for product_name, season_name in product_season:
    footnote = 'Production-Area-Yield time-series of %s - %s - %s' % (country_iso, product_name, season_name)
    fn_save = '../figures/%s_line_pay_%s_%s.png' % (country_iso, product_name, season_name)
    sub = df[(df['product'] == product_name) & (df['season_name'] == season_name)]
    fig = PlotLinePAY(sub, year, footnote, fn_save)
    fig.show()
# Out:
# ../figures/NE_line_pay_Millet_Main.png is saved.
# ../figures/NE_line_pay_Sorghum_Main.png is saved.
# ../figures/NE_line_pay_Maize_Main.png is saved.
# ../figures/NE_line_pay_Rice_Main.png is saved.
# ../figures/NE_line_pay_Fonio_Main.png is saved.
