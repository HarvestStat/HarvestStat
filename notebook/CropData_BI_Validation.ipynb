# %% [markdown]
# # HarvestStat Data Analysis - Brundi

# %% [markdown]
# ## Issue 1: Data quality

# %%
import json, requests
import pandas as pd
host = 'https://fdw.fews.net'
parameters = {
    'format': 'json',
    'country': 'Burundi',
    'product': ['R011','R012','R013','R014','R015','R017','R018'],
    'survey_type': 'crop:best'
}
endpoint = '/api/cropproductionindicatorvalue/'
response = requests.get(host + endpoint, params=parameters, proxies={})
response.raise_for_status()
df = pd.DataFrame.from_records(response.json())
df[df['admin_1'] == 'Bubanza'].pivot_table(index='season_date', columns=['product','indicator'], values='value')
# Out:
# product     Banana (unspecified)                              Beans (mixed)  \
# indicator           Area Planted Quantity Produced      Yield  Area Planted
# season_date
# 1996-02-01                   NaN            4032.9        NaN           NaN
# 1996-06-01                   NaN            2166.9        NaN           NaN
# 1996-09-01                   NaN            3852.3        NaN           NaN
# 1997-02-01                   NaN               NaN        NaN           NaN
# 1997-06-01                   NaN               NaN        NaN           NaN
# 1997-09-01                   NaN            3852.3        NaN           NaN
# 1998-02-01                   NaN               NaN        NaN           NaN
# 1998-06-01                   NaN               NaN        NaN           NaN
# 1998-09-01                   NaN            3852.3        NaN           NaN
# 2000-02-01                   NaN            4254.0        NaN           NaN
# 2000-06-01                   NaN            2366.1        NaN           NaN
# 2000-09-01                   NaN            3575.7        NaN           NaN
# 2001-02-01                   NaN            4339.1        NaN           NaN
# 2001-06-01                   NaN            2404.0        NaN           NaN
# 2001-09-01                   NaN            3611.5        NaN           NaN
# 2002-02-01                   NaN            4512.7        NaN           NaN
# 2002-06-01                   NaN            2464.0        NaN           NaN
# 2002-09-01                   NaN            3683.7        NaN           NaN
# 2003-02-01                   NaN            4377.3        NaN           NaN
# 2003-06-01                   NaN            2390.1        NaN           NaN
# 2003-09-01                   NaN            3495.5        NaN           NaN
# 2005-02-01                   NaN            4598.8        NaN           NaN
# 2005-06-01                   NaN            2510.6        NaN           NaN
# 2005-09-01                   NaN            3560.2        NaN           NaN
# 2006-02-01                   NaN            4828.7        NaN           NaN
# 2006-06-01                   NaN            2403.0        NaN           NaN
# 2006-09-01                   NaN            3311.0        NaN           NaN
# 2007-02-01                   NaN            4973.6        NaN           NaN
# 2007-06-01                   NaN            2400.0        NaN           NaN
# 2007-09-01                   NaN            3476.6        NaN           NaN
# 2008-02-01                   NaN            4973.6        NaN           NaN
# 2008-06-01                   NaN            2640.0        NaN           NaN
# 2008-09-01                   NaN            3546.1        NaN           NaN
# 2009-02-01                   NaN            3729.0        NaN           NaN
# 2009-06-01                   NaN            7104.0        NaN           NaN
# 2009-09-01                   NaN            3652.5        NaN           NaN
# 2010-02-01                   NaN            3915.0        NaN           NaN
# 2010-06-01                   NaN            1946.0        NaN           NaN
# 2010-09-01                   NaN            2686.0        NaN           NaN
# 2011-02-01                   NaN            3993.0        NaN           NaN
# 2011-06-01                   NaN            2008.0        NaN           NaN
# 2011-09-01                   NaN            2606.0        NaN           NaN
# 2012-02-01                 111.0            2888.0  26.018018           NaN
# 2012-06-01                 175.0            1603.0   9.160000           NaN
# 2012-09-01                  22.0              42.0   1.909091        1424.0
# 2013-02-01                  43.0            1084.0  25.209302           NaN
# 2013-06-01                 121.0            2504.0  20.694215           NaN
# 2013-09-01                  29.0             102.0   3.517241           NaN
# 2014-02-01                 325.0            4014.0  12.350769           NaN
# 2014-06-01                 324.0            2305.0   7.114198           NaN
# 2014-09-01                  39.0             233.0   5.974359           NaN
# 2015-09-01                   NaN             455.0        NaN           NaN
#
# product                                   Bush bean                    \
# indicator   Quantity Produced    Yield Area Planted Quantity Produced
# season_date
# 1996-02-01             2442.0      NaN          NaN               NaN
# 1996-06-01               77.0      NaN          NaN               NaN
# 1996-09-01             1721.0      NaN          NaN               NaN
# 1997-02-01             2442.0      NaN          NaN               NaN
# 1997-06-01               77.0      NaN          NaN               NaN
# 1997-09-01             1721.0      NaN          NaN               NaN
# 1998-02-01             2442.0      NaN          NaN               NaN
# 1998-06-01               77.0      NaN          NaN               NaN
# 1998-09-01             1721.0      NaN          NaN               NaN
# 2000-02-01             2242.0      NaN          NaN               NaN
# 2000-06-01             1282.0      NaN          NaN               NaN
# 2000-09-01             2325.0      NaN          NaN               NaN
# 2001-02-01             2928.0      NaN          NaN               NaN
# 2001-06-01             1279.0      NaN          NaN               NaN
# 2001-09-01             2558.0      NaN          NaN               NaN
# 2002-02-01             2811.0      NaN          NaN               NaN
# 2002-06-01             1279.0      NaN          NaN               NaN
# 2002-09-01             2532.0      NaN          NaN               NaN
# 2003-02-01             2839.0      NaN          NaN               NaN
# 2003-06-01             1215.0      NaN          NaN               NaN
# 2003-09-01             2026.0      NaN          NaN               NaN
# 2005-02-01             2562.0      NaN          NaN               NaN
# 2005-06-01             1276.0      NaN          NaN               NaN
# 2005-09-01             1774.0      NaN          NaN               NaN
# 2006-02-01             2639.0      NaN          NaN               NaN
# 2006-06-01             1200.0      NaN          NaN               NaN
# 2006-09-01             1242.0      NaN          NaN               NaN
# 2007-02-01             2586.0      NaN          NaN               NaN
# 2007-06-01             1200.0      NaN          NaN               NaN
# 2007-09-01              994.0      NaN          NaN               NaN
# 2008-02-01             1681.0      NaN          NaN               NaN
# 2008-06-01             1320.0      NaN          NaN               NaN
# 2008-09-01              845.0      NaN          NaN               NaN
# 2009-02-01             1849.0      NaN          NaN               NaN
# 2009-06-01             1122.0      NaN          NaN               NaN
# 2009-09-01              777.0      NaN          NaN               NaN
# 2010-02-01             1664.0      NaN          NaN               NaN
# 2010-06-01             1363.0      NaN          NaN               NaN
# 2010-09-01              699.0      NaN          NaN               NaN
# 2011-02-01             1714.0      NaN          NaN               NaN
# 2011-06-01             1103.0      NaN          NaN               NaN
# 2011-09-01              664.0      NaN          NaN               NaN
# 2012-02-01                NaN      NaN       1295.0            1076.0
# 2012-06-01                NaN      NaN        151.0             136.0
# 2012-09-01             1838.0  1.29073          NaN               NaN
# 2013-02-01                NaN      NaN        947.0            1854.0
# 2013-06-01                NaN      NaN        223.0              89.0
# 2013-09-01                NaN      NaN       1661.0            1318.0
# 2014-02-01                NaN      NaN       2223.0            1457.0
# 2014-06-01                NaN      NaN        326.0             245.0
# 2014-09-01                NaN      NaN        831.0            1737.0
# 2015-09-01                NaN      NaN       4478.0            3525.0
#
# product                    Cassava  ... Soybean (unspecified) Sweet Potatoes  \
# indicator       Yield Area Planted  ...                 Yield   Area Planted
# season_date                         ...
# 1996-02-01        NaN          NaN  ...                   NaN            NaN
# 1996-06-01        NaN          NaN  ...                   NaN            NaN
# 1996-09-01        NaN          NaN  ...                   NaN            NaN
# 1997-02-01        NaN          NaN  ...                   NaN            NaN
# 1997-06-01        NaN          NaN  ...                   NaN            NaN
# 1997-09-01        NaN          NaN  ...                   NaN            NaN
# 1998-02-01        NaN          NaN  ...                   NaN            NaN
# 1998-06-01        NaN          NaN  ...                   NaN            NaN
# 1998-09-01        NaN          NaN  ...                   NaN            NaN
# 2000-02-01        NaN          NaN  ...                   NaN            NaN
# 2000-06-01        NaN          NaN  ...                   NaN            NaN
# 2000-09-01        NaN          NaN  ...                   NaN            NaN
# 2001-02-01        NaN          NaN  ...                   NaN            NaN
# 2001-06-01        NaN          NaN  ...                   NaN            NaN
# 2001-09-01        NaN          NaN  ...                   NaN            NaN
# 2002-02-01        NaN          NaN  ...                   NaN            NaN
# 2002-06-01        NaN          NaN  ...                   NaN            NaN
# 2002-09-01        NaN          NaN  ...                   NaN            NaN
# 2003-02-01        NaN          NaN  ...                   NaN            NaN
# 2003-06-01        NaN          NaN  ...                   NaN            NaN
# 2003-09-01        NaN          NaN  ...                   NaN            NaN
# 2005-02-01        NaN          NaN  ...                   NaN            NaN
# 2005-06-01        NaN          NaN  ...                   NaN            NaN
# 2005-09-01        NaN          NaN  ...                   NaN            NaN
# 2006-02-01        NaN          NaN  ...                   NaN            NaN
# 2006-06-01        NaN          NaN  ...                   NaN            NaN
# 2006-09-01        NaN          NaN  ...                   NaN            NaN
# 2007-02-01        NaN          NaN  ...                   NaN            NaN
# 2007-06-01        NaN          NaN  ...                   NaN            NaN
# 2007-09-01        NaN          NaN  ...                   NaN            NaN
# 2008-02-01        NaN          NaN  ...                   NaN            NaN
# 2008-06-01        NaN          NaN  ...                   NaN            NaN
# 2008-09-01        NaN          NaN  ...                   NaN            NaN
# 2009-02-01        NaN          NaN  ...                   NaN            NaN
# 2009-06-01        NaN          NaN  ...                   NaN            NaN
# 2009-09-01        NaN          NaN  ...                   NaN            NaN
# 2010-02-01        NaN          NaN  ...                   NaN            NaN
# 2010-06-01        NaN          NaN  ...                   NaN            NaN
# 2010-09-01        NaN          NaN  ...                   NaN            NaN
# 2011-02-01        NaN          NaN  ...                   NaN            NaN
# 2011-06-01        NaN          NaN  ...                   NaN            NaN
# 2011-09-01        NaN          NaN  ...                   NaN            NaN
# 2012-02-01   0.830888       7935.0  ...              2.054545          437.0
# 2012-06-01   0.900662       8827.0  ...                   NaN         1042.0
# 2012-09-01        NaN       5094.0  ...              0.000000          698.0
# 2013-02-01   1.957761       7221.0  ...              0.600000          367.0
# 2013-06-01   0.399103       7578.0  ...                   NaN         1166.0
# 2013-09-01   0.793498       8999.0  ...              0.100000          366.0
# 2014-02-01   0.655421       6835.0  ...              0.651685          524.0
# 2014-06-01   0.751534       9713.0  ...                   NaN          900.0
# 2014-09-01   2.090253       3288.0  ...              0.496933          405.0
# 2015-09-01   0.787182       8406.0  ...              0.000000          232.0
#
# product                                  Taro, move to 1594AA  \
# indicator   Quantity Produced      Yield         Area Planted
# season_date
# 1996-02-01            821.000        NaN                  NaN
# 1996-06-01             21.000        NaN                  NaN
# 1996-09-01            956.000        NaN                  NaN
# 1997-02-01                NaN        NaN                  NaN
# 1997-06-01                NaN        NaN                  NaN
# 1997-09-01                NaN        NaN                  NaN
# 1998-02-01                NaN        NaN                  NaN
# 1998-06-01                NaN        NaN                  NaN
# 1998-09-01                NaN        NaN                  NaN
# 2000-02-01            856.000        NaN                  NaN
# 2000-06-01            241.000        NaN                  NaN
# 2000-09-01           1078.000        NaN                  NaN
# 2001-02-01           1027.000        NaN                  NaN
# 2001-06-01            272.000        NaN                  NaN
# 2001-09-01           1121.000        NaN                  NaN
# 2002-02-01           1078.000        NaN                  NaN
# 2002-06-01            312.000        NaN                  NaN
# 2002-09-01           1255.000        NaN                  NaN
# 2003-02-01           1046.000        NaN                  NaN
# 2003-06-01            303.000        NaN                  NaN
# 2003-09-01           1192.000        NaN                  NaN
# 2005-02-01           1142.000        NaN                  NaN
# 2005-06-01            318.000        NaN                  NaN
# 2005-09-01           1073.000        NaN                  NaN
# 2006-02-01           1165.000        NaN                  NaN
# 2006-06-01            350.000        NaN                  NaN
# 2006-09-01            966.000        NaN                  NaN
# 2007-02-01           1258.000        NaN                  NaN
# 2007-06-01            400.000        NaN                  NaN
# 2007-09-01            869.000        NaN                  NaN
# 2008-02-01           1271.000        NaN                  NaN
# 2008-06-01            940.000        NaN                  NaN
# 2008-09-01            895.000        NaN                  NaN
# 2009-02-01            411.000        NaN                  NaN
# 2009-06-01            230.000        NaN                  NaN
# 2009-09-01            895.000        NaN                  NaN
# 2010-02-01            452.000        NaN                  NaN
# 2010-06-01            143.000        NaN                  NaN
# 2010-09-01            295.000        NaN                  NaN
# 2011-02-01            461.000        NaN                  NaN
# 2011-06-01            129.000        NaN                  NaN
# 2011-09-01            298.000        NaN                  NaN
# 2012-02-01           4292.000   9.821510                403.0
# 2012-06-01           1653.000   1.586372                 72.0
# 2012-09-01           2597.000   3.720630                385.0
# 2013-02-01           2356.140   6.420000                350.0
# 2013-06-01           6051.540   5.190000                 23.0
# 2013-09-01           1873.188   5.118000                 97.0
# 2014-02-01           6898.000  13.164122                252.0
# 2014-06-01           5684.000   6.315556                  NaN
# 2014-09-01           2267.000   5.597531                104.0
# 2015-09-01           2171.000   9.357759                  9.0
#
# product                                          Yams                    \
# indicator   Quantity Produced      Yield Area Planted Quantity Produced
# season_date
# 1996-02-01            4356.00        NaN          NaN               NaN
# 1996-06-01            3137.00        NaN          NaN               NaN
# 1996-09-01            5578.00        NaN          NaN               NaN
# 1997-02-01            4576.00        NaN          NaN               NaN
# 1997-06-01            3294.00        NaN          NaN               NaN
# 1997-09-01            5578.00        NaN          NaN               NaN
# 1998-02-01            4576.00        NaN          NaN               NaN
# 1998-06-01            3294.00        NaN          NaN               NaN
# 1998-09-01            5578.00        NaN          NaN               NaN
# 2000-02-01            5045.00        NaN          NaN               NaN
# 2000-06-01            2835.00        NaN          NaN               NaN
# 2000-09-01            4035.00        NaN          NaN               NaN
# 2001-02-01            5196.00        NaN          NaN               NaN
# 2001-06-01            3204.00        NaN          NaN               NaN
# 2001-09-01            3874.00        NaN          NaN               NaN
# 2002-02-01            5196.00        NaN          NaN               NaN
# 2002-06-01            3204.00        NaN          NaN               NaN
# 2002-09-01            3874.00        NaN          NaN               NaN
# 2003-02-01            5196.00        NaN          NaN               NaN
# 2003-06-01                NaN        NaN          NaN               NaN
# 2003-09-01            3796.00        NaN          NaN               NaN
# 2005-02-01            4676.00        NaN          NaN               NaN
# 2005-06-01                NaN        NaN          NaN               NaN
# 2005-09-01            3534.00        NaN          NaN               NaN
# 2006-02-01            4676.00        NaN          NaN               NaN
# 2006-06-01                NaN        NaN          NaN               NaN
# 2006-09-01            3181.00        NaN          NaN               NaN
# 2007-02-01            4723.00        NaN          NaN               NaN
# 2007-06-01                NaN        NaN          NaN               NaN
# 2007-09-01            3181.00        NaN          NaN               NaN
# 2008-02-01            4723.00        NaN          NaN               NaN
# 2008-06-01                NaN        NaN          NaN               NaN
# 2008-09-01            3181.00        NaN          NaN               NaN
# 2009-02-01            1513.00        NaN          NaN               NaN
# 2009-06-01             823.00        NaN          NaN               NaN
# 2009-09-01            3149.00        NaN          NaN               NaN
# 2010-02-01            1543.00        NaN          NaN               NaN
# 2010-06-01                NaN        NaN          NaN               NaN
# 2010-09-01             999.00        NaN          NaN               NaN
# 2011-02-01            1558.00        NaN          NaN               NaN
# 2011-06-01                NaN        NaN          NaN               NaN
# 2011-09-01             999.00        NaN          NaN               NaN
# 2012-02-01            3319.00   8.235732         46.0             214.0
# 2012-06-01             196.00   2.722222         10.0               NaN
# 2012-09-01                NaN   0.000000          7.0               NaN
# 2013-02-01            1435.00   4.100000          NaN               NaN
# 2013-06-01              92.92   4.040000          NaN               NaN
# 2013-09-01             970.00  10.000000          NaN               NaN
# 2014-02-01            3239.00  12.853175         63.0               NaN
# 2014-06-01                NaN        NaN          NaN               NaN
# 2014-09-01                NaN   0.000000          NaN               NaN
# 2015-09-01                NaN   0.000000          NaN               NaN
#
# product
# indicator       Yield
# season_date
# 1996-02-01        NaN
# 1996-06-01        NaN
# 1996-09-01        NaN
# 1997-02-01        NaN
# 1997-06-01        NaN
# 1997-09-01        NaN
# 1998-02-01        NaN
# 1998-06-01        NaN
# 1998-09-01        NaN
# 2000-02-01        NaN
# 2000-06-01        NaN
# 2000-09-01        NaN
# 2001-02-01        NaN
# 2001-06-01        NaN
# 2001-09-01        NaN
# 2002-02-01        NaN
# 2002-06-01        NaN
# 2002-09-01        NaN
# 2003-02-01        NaN
# 2003-06-01        NaN
# 2003-09-01        NaN
# 2005-02-01        NaN
# 2005-06-01        NaN
# 2005-09-01        NaN
# 2006-02-01        NaN
# 2006-06-01        NaN
# 2006-09-01        NaN
# 2007-02-01        NaN
# 2007-06-01        NaN
# 2007-09-01        NaN
# 2008-02-01        NaN
# 2008-06-01        NaN
# 2008-09-01        NaN
# 2009-02-01        NaN
# 2009-06-01        NaN
# 2009-09-01        NaN
# 2010-02-01        NaN
# 2010-06-01        NaN
# 2010-09-01        NaN
# 2011-02-01        NaN
# 2011-06-01        NaN
# 2011-09-01        NaN
# 2012-02-01   4.652174
# 2012-06-01   0.000000
# 2012-09-01   0.000000
# 2013-02-01        NaN
# 2013-06-01        NaN
# 2013-09-01        NaN
# 2014-02-01   0.000000
# 2014-06-01        NaN
# 2014-09-01        NaN
# 2015-09-01        NaN
#
# [52 rows x 57 columns]

# %%
df[['season_name','season_date','start_date']].drop_duplicates().sort_values('season_name')
# Out:
#       season_name season_date  start_date
# 0        Season A  1998-09-01  1999-01-01
# 3251     Season A  2002-09-01  2003-01-01
# 3208     Season A  2005-09-01  2006-01-01
# 3273     Season A  2001-09-01  2002-01-01
# 3186     Season A  2006-09-01  2007-01-01
# 3295     Season A  2000-09-01  2001-01-01
# 3164     Season A  2007-09-01  2008-01-01
# 14196    Season A  2011-09-01  2012-01-01
# 3230     Season A  2003-09-01  2004-01-01
# 14219    Season A  2010-09-01  2011-01-01
# 3142     Season A  2008-09-01  2009-01-01
# 3117     Season A  2009-09-01  2010-01-01
# 16632    Season A  2015-09-01  2016-01-01
# 16645    Season A  2014-09-01  2015-01-01
# 32       Season A  1996-09-01  1997-01-01
# 16688    Season A  2013-09-01  2014-01-01
# 16       Season A  1997-09-01  1998-01-01
# 16730    Season A  2012-09-01  2013-01-01
# 14209    Season B  2011-02-01  2011-05-01
# 3308     Season B  2000-02-01  2000-05-01
# 16672    Season B  2014-02-01  2014-05-01
# 3286     Season B  2001-02-01  2001-05-01
# 16715    Season B  2013-02-01  2013-05-01
# 3264     Season B  2002-02-01  2002-05-01
# 14233    Season B  2010-02-01  2010-05-01
# 3242     Season B  2003-02-01  2003-05-01
# 16757    Season B  2012-02-01  2012-05-01
# 3221     Season B  2005-02-01  2005-05-01
# 9        Season B  1998-02-01  1998-05-01
# 25       Season B  1997-02-01  1997-05-01
# 46       Season B  1996-02-01  1996-05-01
# 3155     Season B  2008-02-01  2008-05-01
# 3177     Season B  2007-02-01  2007-05-01
# 3132     Season B  2009-02-01  2009-05-01
# 3199     Season B  2006-02-01  2006-05-01
# 5        Season C  1998-06-01  1998-08-01
# 3257     Season C  2002-06-01  2002-08-01
# 16703    Season C  2013-06-01  2013-08-01
# 21       Season C  1997-06-01  1997-08-01
# 3215     Season C  2005-06-01  2005-08-01
# 16662    Season C  2014-06-01  2014-08-01
# 40       Season C  1996-06-01  1996-08-01
# 3301     Season C  2000-06-01  2000-08-01
# 3124     Season C  2009-06-01  2009-08-01
# 14227    Season C  2010-06-01  2010-08-01
# 16746    Season C  2012-06-01  2012-08-01
# 3149     Season C  2008-06-01  2008-08-01
# 14204    Season C  2011-06-01  2011-08-01
# 3279     Season C  2001-06-01  2001-08-01
# 3171     Season C  2007-06-01  2007-08-01
# 3193     Season C  2006-06-01  2006-08-01
# 3237     Season C  2003-06-01  2003-08-01

# %% [markdown]
# ## Validation with FAOSTAT and CHIRPS Precipitation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import proplot as pplot
# Load Crop Data ------------------------------------- #
# country_name, product_name_fdw, product_name_fao,  = 'Burundi', 'Maize', 'Maize (corn)'
country_name, product_name_fdw, product_name_fao,  = 'Burundi', 'Cassava', 'Cassava'
shape_code, prcp_start_month, prcp_season_name, prcp_year_offset = 'BI1998A0', 10, 'Oct-May PRCP (mm)', +1
# HarvestStat
season_list = [
    ['Season A', -1],
    ['Season B', 0],
    ['Season C', 0]
]
container = []
for season_name, harvest_year_shift in season_list:
    df = pd.read_csv('../public/hvstat_data.csv', index_col=0)
    df = df[
        (df['country'] == country_name) &
        (df['season_name'] == season_name) &
        (df['product'].isin([product_name_fdw])) &
        (df['indicator'] == 'production')
    ].copy()
    df['year'] = df['harvest_year'] + harvest_year_shift
    container.append(df.pivot_table(index='year',columns='product',values='value',aggfunc='sum').squeeze())
data_hs = pd.concat(container, axis=1).sort_index().sum(axis=1, min_count=1)
# FAO-STAT
df = pd.read_csv('../data/crop/adm_fao_stat.csv', index_col=0)
data_fao = df[
    (df['cnt_name'] == country_name) &
    (df['cpc2_name'] == product_name_fao) &
    (df['indicator'] == 'Production')
].set_index('year')['value']
# Merge
data = pd.concat([data_fao,data_hs], axis=1, keys=['FAO','HS']).sort_index()
data = data.reindex(np.array(range(1982,2024)))
# Load precipitation --------------------------------- #
fn = '../data/prcp_chirps-v2.hdf'
prcp_nat = pd.read_hdf(fn)[shape_code].resample('1M').agg('sum')
prcp_nat.index = prcp_nat.index.map(lambda x: x.replace(day=1))
prcp_nat.name = 'PRCP'
prcp_nat.index = prcp_nat.index + pd.DateOffset(years=prcp_year_offset)
# Forward rolling summation
indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=10)   # Forward Rolling Window
prcp_nat = prcp_nat.rolling(window=indexer, min_periods=3).sum()
prcp_nat = prcp_nat[prcp_nat.index.month == prcp_start_month]                      # Start month
prcp_nat = prcp_nat.groupby(prcp_nat.index.year).sum()
prcp_label = prcp_season_name
# Correlations
corr_value = pd.concat([data,prcp_nat],axis=1).corr()
print(f'{season_name}-{product_name_fdw} Correlation:\n{corr_value}')
# ---------------------------------------------------- #
# Comparison with Precipitation ---------------------- #
fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
data.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
# years = data.index
# ax1.set_xticks(years)
# ax1.set_xticklabels(['%02d'% yr for yr in np.mod(years,100)])
ax1.set_xlim([data.index[0]-0.5, data.index[-1]+0.5])
ax1.set_xlabel('Year')
ax1.set_ylabel('National Maize Production (ton)')
ax1.patch.set_facecolor('white')
# Precipitation
year, value = prcp_nat.index, prcp_nat.values
ax2 = ax1.twinx()
plt.bar(year, value, alpha=.25, color='grey')
ax2.set_ylim([0, value.max()*1.3])
ax2.set_ylabel(prcp_label + ' (year+%d)'%prcp_year_offset, labelpad=10)
ax2.grid(False)
ax1.set_zorder(1)  
ax1.patch.set_visible(False)  # prevents ax1 from hiding ax2
ax1.legend(loc='upper left')
ax1.annotate(
    'R: %.3f (HS)\nR: %.3f (FAO)' % (corr_value.loc['HS','PRCP'], corr_value.loc['FAO','PRCP']), 
    xy=(1, 0.2), xycoords='axes fraction', fontsize=10,
    xytext=(-5, -5), textcoords='offset points',
    ha='right', va='top'
)
title = f'{country_name} Annual (Seasons ABC)-{product_name_fdw}-Production and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()
# ---------------------------------------------------- #
# Out:
# Season C-Cassava Correlation:
#            FAO        HS      PRCP
# FAO   1.000000  0.736788  0.404691
# HS    0.736788  1.000000  0.268374
# PRCP  0.404691  0.268374  1.000000
