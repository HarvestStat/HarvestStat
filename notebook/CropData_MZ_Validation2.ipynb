# %% [markdown]
# # HarvestStat Data Analysis - Mozambique

# %% [markdown]
# ## Issue 1: Wrong duplicates of Sweet Potatoes and Cassava in Mozambique

# %%
import json, requests
import pandas as pd
host = 'https://fdw.fews.net'
auth = tuple(json.loads(open('token.json', "r").read()))
parameters = {
    'format': 'json',
    'country': 'Mozambique',
    'product': 'Sweet Potatoes',
    'survey_type': 'crop:best'
}
endpoint = '/api/cropproductionindicatorvalue/'
response = requests.get(host + endpoint, auth=auth, params=parameters, proxies={})
response.raise_for_status()
df = pd.DataFrame.from_records(response.json())
df[df['indicator'] == 'Quantity Produced'].pivot_table(index='season_year', columns='fnid', values='value', aggfunc='max')
# Out:
# fnid               MZ1990A101  MZ1990A102  MZ1990A103  MZ1990A104  MZ1990A105  \
# season_year
# Main harvest 2002     11944.0     24003.0      6191.0     48742.0     21740.0
# Main harvest 2005   6151144.0  44042590.0  17676888.0  58349520.0     21350.0
# Main harvest 2006      3060.0     35360.0      4360.0     80690.0     22420.0
# Main harvest 2007      7910.0     55540.0      7830.0    177530.0     15010.0
# Main harvest 2008      6450.0     49690.0      4530.0     46480.0     39000.0
# Main harvest 2012      1038.0     45711.0      1739.0     63538.0      6765.0
# Main harvest 2013         NaN         NaN         NaN         NaN         NaN
# Main harvest 2014         NaN         NaN         NaN         NaN         NaN
# Main harvest 2015         NaN         NaN         NaN         NaN         NaN
# Main harvest 2016         NaN         NaN         NaN         NaN         NaN
# Main harvest 2017         NaN         NaN         NaN         NaN         NaN
# Main harvest 2018         NaN         NaN         NaN         NaN         NaN
# Main harvest 2019         NaN         NaN         NaN         NaN         NaN
# Main harvest 2020         NaN         NaN         NaN         NaN         NaN
# Main harvest 2021         NaN         NaN         NaN         NaN         NaN
# Main harvest 2022         NaN         NaN         NaN         NaN         NaN
#
# fnid               MZ1990A106  MZ1990A107  MZ1990A108   MZ1990A109  \
# season_year
# Main harvest 2002         NaN     21830.0     34890.0      22772.0
# Main harvest 2005  34277260.0  26444470.0  30233660.0  176116800.0
# Main harvest 2006         NaN     11100.0     30700.0      93130.0
# Main harvest 2007         NaN      8690.0     19930.0      74530.0
# Main harvest 2008         NaN      1760.0     51310.0      91500.0
# Main harvest 2012         NaN      8808.0     67681.0      59741.0
# Main harvest 2013         NaN         NaN         NaN          NaN
# Main harvest 2014         NaN         NaN         NaN          NaN
# Main harvest 2015         NaN         NaN         NaN          NaN
# Main harvest 2016         NaN         NaN         NaN          NaN
# Main harvest 2017         NaN         NaN         NaN          NaN
# Main harvest 2018         NaN         NaN         NaN          NaN
# Main harvest 2019         NaN         NaN         NaN          NaN
# Main harvest 2020         NaN         NaN         NaN          NaN
# Main harvest 2021         NaN         NaN         NaN          NaN
# Main harvest 2022         NaN         NaN         NaN          NaN
#
# fnid                MZ1990A110  ...  MZ2021A101  MZ2021A102  MZ2021A103  \
# season_year                     ...
# Main harvest 2002     137110.0  ...         NaN         NaN         NaN
# Main harvest 2005  310190600.0  ...         NaN         NaN         NaN
# Main harvest 2006      97400.0  ...         NaN         NaN         NaN
# Main harvest 2007     288610.0  ...         NaN         NaN         NaN
# Main harvest 2008     106440.0  ...         NaN         NaN         NaN
# Main harvest 2012      43305.0  ...         NaN         NaN         NaN
# Main harvest 2013          NaN  ...         NaN         NaN         NaN
# Main harvest 2014          NaN  ...         NaN         NaN         NaN
# Main harvest 2015          NaN  ...         NaN         NaN         NaN
# Main harvest 2016          NaN  ...         NaN         NaN         NaN
# Main harvest 2017          NaN  ...         NaN         NaN         NaN
# Main harvest 2018          NaN  ...         NaN         NaN         NaN
# Main harvest 2019          NaN  ...         NaN         NaN         NaN
# Main harvest 2020          NaN  ...         NaN         NaN         NaN
# Main harvest 2021          NaN  ...       539.0     29575.0      2350.0
# Main harvest 2022          NaN  ...       555.0     30462.0      2421.0
#
# fnid               MZ2021A104  MZ2021A105  MZ2021A107  MZ2021A108  MZ2021A109  \
# season_year
# Main harvest 2002         NaN         NaN         NaN         NaN         NaN
# Main harvest 2005         NaN         NaN         NaN         NaN         NaN
# Main harvest 2006         NaN         NaN         NaN         NaN         NaN
# Main harvest 2007         NaN         NaN         NaN         NaN         NaN
# Main harvest 2008         NaN         NaN         NaN         NaN         NaN
# Main harvest 2012         NaN         NaN         NaN         NaN         NaN
# Main harvest 2013         NaN         NaN         NaN         NaN         NaN
# Main harvest 2014         NaN         NaN         NaN         NaN         NaN
# Main harvest 2015         NaN         NaN         NaN         NaN         NaN
# Main harvest 2016         NaN         NaN         NaN         NaN         NaN
# Main harvest 2017         NaN         NaN         NaN         NaN         NaN
# Main harvest 2018         NaN         NaN         NaN         NaN         NaN
# Main harvest 2019         NaN         NaN         NaN         NaN         NaN
# Main harvest 2020         NaN         NaN         NaN         NaN         NaN
# Main harvest 2021     45917.0     25960.0     12020.0     13420.0     31928.0
# Main harvest 2022     47294.0     26739.0     12381.0     13823.0     32886.0
#
# fnid               MZ2021A110  MZ2021A111
# season_year
# Main harvest 2002         NaN         NaN
# Main harvest 2005         NaN         NaN
# Main harvest 2006         NaN         NaN
# Main harvest 2007         NaN         NaN
# Main harvest 2008         NaN         NaN
# Main harvest 2012         NaN         NaN
# Main harvest 2013         NaN         NaN
# Main harvest 2014         NaN         NaN
# Main harvest 2015         NaN         NaN
# Main harvest 2016         NaN         NaN
# Main harvest 2017         NaN         NaN
# Main harvest 2018         NaN         NaN
# Main harvest 2019         NaN         NaN
# Main harvest 2020         NaN         NaN
# Main harvest 2021     51227.0    137997.0
# Main harvest 2022     52763.0    142137.0
#
# [16 rows x 42 columns]

# %%
df[
    (df['fnid']=='MZ1990A101') &
    (df['indicator'] == 'Quantity Produced') &
    (df['season_year'] == 'Main harvest 2005')
].T
# Out:
#                                                                                62  \
# country                                                                Mozambique
# source_organization             Ministério da Agricultura e Segurança Alimenta...
# source_document                      Anuário de Estatísticas Agrárias, Mozambique
# geographic_unit_full_name                                Cabo Delgado, Mozambique
# geographic_unit_name                                                 Cabo Delgado
# fnid                                                                   MZ1990A101
# admin_0                                                                Mozambique
# admin_1                                                              Cabo Delgado
# admin_2                                                                      None
# admin_3                                                                      None
# admin_4                                                                      None
# population_group
# crop_production_system                                                   All (PS)
# start_date                                                             2005-04-01
# period_date                                                            2005-04-30
# season_name                                                          Main harvest
# season_type                                                               Harvest
# season_date                                                            2005-04-30
# season_year                                                     Main harvest 2005
# document_type                                    Final Government Crop Production
# preference_rating                                                            None
# indicator_group                                                   Crop Production
# indicator                                                       Quantity Produced
# status                                                                  Collected
# value                                                                        94.0
# population                                                                1632119
# value_per_capita                                                         0.000058
# product                                                   Sweet Potatoes (Orange)
# country_code                                                                   MZ
# locality_name                   Cabo Delgado, Mozambique (01/01/1990 - 12/31/2...
# unit                                                                            t
# unit_name                                                                   Tonne
# cpcv2                                                                    R01591AB
# cpcv2_description                                          Sweet potatoes, orange
# geographic_group                                                   Eastern Africa
# fewsnet_region                                                    Southern Africa
# id                                                                       34649216
# datacollectionperiod                                                       327946
# datacollection                                                             342278
# datasourcedocument                                                           6832
# datasourceorganization                                                       2067
# indicator_abbreviation                                              crop:quantity
# locality                                                                   118831
# geographic_unit                                                            226876
# season                                                                         71
# dataseries                                                                7045575
# dataseries_name                 Anuário de Estatísticas Agrárias, Mozambique: ...
# specialization_type             /SurveyIndicatorValue/CropProductionIndicatorV...
# dataseries_specialization_type  /SurveyPopulationIndicator/CropProductionIndic...
# data_usage_policy                                                          Public
# created                                                       2024-03-05T23:47:29
# modified                                                      2024-03-05T23:47:29
# status_changed                                                2024-03-05T23:51:08
# collection_status                                                       Published
# collection_status_changed                                     2024-03-05T23:54:59
# collection_schedule                                                        Ad Hoc
# collection_date                                                        2005-04-30
# publication_name                Anuário de Estatisticas Agrárias, 2002-2011, M...
#
#                                                                                63  \
# country                                                                Mozambique
# source_organization             Ministério da Agricultura e Segurança Alimenta...
# source_document                      Anuário de Estatísticas Agrárias, Mozambique
# geographic_unit_full_name                                Cabo Delgado, Mozambique
# geographic_unit_name                                                 Cabo Delgado
# fnid                                                                   MZ1990A101
# admin_0                                                                Mozambique
# admin_1                                                              Cabo Delgado
# admin_2                                                                      None
# admin_3                                                                      None
# admin_4                                                                      None
# population_group
# crop_production_system                                                   All (PS)
# start_date                                                             2005-04-01
# period_date                                                            2005-04-30
# season_name                                                          Main harvest
# season_type                                                               Harvest
# season_date                                                            2005-04-30
# season_year                                                     Main harvest 2005
# document_type                                    Final Government Crop Production
# preference_rating                                                            None
# indicator_group                                                   Crop Production
# indicator                                                       Quantity Produced
# status                                                                  Collected
# value                                                                    3073.992
# population                                                                1632119
# value_per_capita                                                         0.001883
# product                                               Sweet Potatoes (Non-Orange)
# country_code                                                                   MZ
# locality_name                   Cabo Delgado, Mozambique (01/01/1990 - 12/31/2...
# unit                                                                            t
# unit_name                                                                   Tonne
# cpcv2                                                                    R01591AC
# cpcv2_description                                      Sweet potatoes, non-orange
# geographic_group                                                   Eastern Africa
# fewsnet_region                                                    Southern Africa
# id                                                                       34649217
# datacollectionperiod                                                       327946
# datacollection                                                             342278
# datasourcedocument                                                           6832
# datasourceorganization                                                       2067
# indicator_abbreviation                                              crop:quantity
# locality                                                                   118831
# geographic_unit                                                            226876
# season                                                                         71
# dataseries                                                                7045576
# dataseries_name                 Anuário de Estatísticas Agrárias, Mozambique: ...
# specialization_type             /SurveyIndicatorValue/CropProductionIndicatorV...
# dataseries_specialization_type  /SurveyPopulationIndicator/CropProductionIndic...
# data_usage_policy                                                          Public
# created                                                       2024-03-05T23:47:29
# modified                                                      2024-03-05T23:47:29
# status_changed                                                2024-03-05T23:51:08
# collection_status                                                       Published
# collection_status_changed                                     2024-03-05T23:54:59
# collection_schedule                                                        Ad Hoc
# collection_date                                                        2005-04-30
# publication_name                Anuário de Estatisticas Agrárias, 2002-2011, M...
#
#                                                                                64
# country                                                                Mozambique
# source_organization             Ministério da Agricultura e Segurança Alimenta...
# source_document                                        FEWS Agro_Maps, Mozambique
# geographic_unit_full_name                                Cabo Delgado, Mozambique
# geographic_unit_name                                                 Cabo Delgado
# fnid                                                                   MZ1990A101
# admin_0                                                                Mozambique
# admin_1                                                              Cabo Delgado
# admin_2                                                                      None
# admin_3                                                                      None
# admin_4                                                                      None
# population_group
# crop_production_system                                                   All (PS)
# start_date                                                             2005-04-01
# period_date                                                            2005-04-30
# season_name                                                          Main harvest
# season_type                                                               Harvest
# season_date                                                            2005-04-30
# season_year                                                     Main harvest 2005
# document_type                                    Final Government Crop Production
# preference_rating                                                            None
# indicator_group                                                   Crop Production
# indicator                                                       Quantity Produced
# status                                                                  Collected
# value                                                                   6151144.0
# population                                                                1632119
# value_per_capita                                                         3.768809
# product                                                            Sweet Potatoes
# country_code                                                                   MZ
# locality_name                   Cabo Delgado, Mozambique (01/01/1990 - 12/31/2...
# unit                                                                            t
# unit_name                                                                   Tonne
# cpcv2                                                                    R01591AA
# cpcv2_description                                                  Sweet potatoes
# geographic_group                                                   Eastern Africa
# fewsnet_region                                                    Southern Africa
# id                                                                       34649215
# datacollectionperiod                                                       327947
# datacollection                                                             342279
# datasourcedocument                                                           6831
# datasourceorganization                                                       2067
# indicator_abbreviation                                              crop:quantity
# locality                                                                   118831
# geographic_unit                                                            226876
# season                                                                         71
# dataseries                                                                7045401
# dataseries_name                 FEWS Agro_Maps, Mozambique: Cabo Delgado, Moza...
# specialization_type             /SurveyIndicatorValue/CropProductionIndicatorV...
# dataseries_specialization_type  /SurveyPopulationIndicator/CropProductionIndic...
# data_usage_policy                                                          Public
# created                                                       2024-03-05T23:47:29
# modified                                                      2024-03-05T23:47:29
# status_changed                                                2024-03-05T23:51:08
# collection_status                                                       Published
# collection_status_changed                                     2024-03-05T23:54:59
# collection_schedule                                                        Ad Hoc
# collection_date                                                        2005-04-30
# publication_name                                       FEWS Agro_Maps, Mozambique

# %%
import json, requests
import pandas as pd
host = 'https://fdw.fews.net'
auth = tuple(json.loads(open('token.json', "r").read()))
parameters = {
    'format': 'json',
    'country': 'Mozambique',
    'product': 'Cassava',
    'survey_type': 'crop:best'
}
endpoint = '/api/cropproductionindicatorvalue/'
response = requests.get(host + endpoint, auth=auth, params=parameters, proxies={})
response.raise_for_status()
df = pd.DataFrame.from_records(response.json())
df[df['fnid'] == 'MZ1990A104'].pivot_table(index='season_year', columns='indicator', values='value', aggfunc='max')
# Out:
# indicator    Area Planted  Quantity Produced       Yield
# season_year
# Annual 2000    943.136171        4904.308088    5.200000
# Annual 2001   1260.230244        6553.197268    5.200000
# Annual 2002   1322.856779      214544.086335  162.182399
# Annual 2003   1319.613424        7682.599768    5.821856
# Annual 2004   1401.373641        8408.241845    6.000000
# Annual 2005   1442.076181      237976.000000  165.023182
# Annual 2006   2560.927513      408090.794804  159.352732
# Annual 2007   2521.335909       13933.000000    5.526039
# Annual 2008   2655.044111       14225.000000    5.357726
# Annual 2009   2748.892230       14611.000000    5.315232
# Annual 2010   2602.000000       15262.000000    5.865488
# Annual 2011           NaN       15894.000000         NaN
# Annual 2012  27000.000000      203122.000000    7.523037

# %% [markdown]
# ## Validation with FAOSTAT and CHIRPS Precipitation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load Crop Data ------------------------------------- #
country_name, season_name, product_name_fdw, product_name_fao,  = 'Mozambique', 'Main', 'Maize', 'Maize (corn)'
shape_code, prcp_start_month, prcp_season_name, prcp_year_offset = 'MZ2013A0', 10, 'OND PRCP (mm)', +1
# HarvestStat
df = pd.read_csv('../public/hvstat_data.csv', index_col=0)
df = df[
    (df['country'] == country_name) &
    (df['season_name'] == season_name) &
    (df['product'].isin([product_name_fdw])) &
    (df['indicator'] == 'production')
].copy()
df['year'] = df['harvest_year']
data_hs = df.pivot_table(index='year',columns='product',values='value',aggfunc='sum').squeeze()
# FAO-STAT
df = pd.read_csv('../data/crop/adm_fao_stat.csv', index_col=0)
data_fao = df[
    (df['Area'] == country_name) &
    (df['Item'] == product_name_fao) &
    (df['Element'] == 'Production')
].set_index('Year')['Value']
# Merge
data = pd.concat([data_fao,data_hs], axis=1, keys=['FAO','HS']).sort_index()
data = data.reindex(np.array(range(1982,2024)))
# ---------------------------------------------------- #
# Load precipitation --------------------------------- #
#fn = '../data/prcp_chirps-v2.hdf'
#prcp_nat = pd.read_hdf(fn)[shape_code].resample('1M').agg('sum')
#prcp_nat.index = prcp_nat.index.map(lambda x: x.replace(day=1))
#prcp_nat.name = 'PRCP'
#prcp_nat.index = prcp_nat.index + pd.DateOffset(years=prcp_year_offset)
# Forward rolling summation
#indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=3)   # Forward Rolling Window
#prcp_nat = prcp_nat.rolling(window=indexer, min_periods=3).sum()
#prcp_nat = prcp_nat[prcp_nat.index.month == prcp_start_month]                      # Start month
#prcp_nat = prcp_nat.groupby(prcp_nat.index.year).sum()
#prcp_label = prcp_season_name
# Correlations
#corr_value = pd.concat([data,prcp_nat],axis=1).corr()
#print(f'{season_name}-{product_name_fdw} Correlation:\n{corr_value}')
# ---------------------------------------------------- #
# Comparison with Precipitation ---------------------- #
fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
data.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
# years = data.index
# ax1.set_xticks(years)
# ax1.set_xticklabels(['%02d'% yr for yr in np.mod(years,100)])
#ax1.set_xlim([data.index[0]-0.5, data.index[-1]+0.5])
#ax1.set_xlabel('Year')
#ax1.set_ylabel('National %s Production (ton)' % product_name_fdw)
#ax1.patch.set_facecolor('white')
# Precipitation
#year, value = prcp_nat.index, prcp_nat.values
#ax2 = ax1.twinx()
#plt.bar(year, value, alpha=.25, color='grey')
#ax2.set_ylim([0, value.max()*1.3])
#ax2.set_ylabel(prcp_label + ' (year+%d)'%prcp_year_offset, labelpad=10)
#ax2.grid(False)
#ax1.set_zorder(1)  
#ax1.patch.set_visible(False)  # prevents ax1 from hiding ax2
#ax1.legend(loc='upper left')
#ax1.annotate(
#    'R: %.3f (HS)\nR: %.3f (FAO)' % (corr_value.loc['HS','PRCP'], corr_value.loc['FAO','PRCP']), 
#    xy=(1, 0.2), xycoords='axes fraction', fontsize=10,
#    xytext=(-5, -5), textcoords='offset points',
#    ha='right', va='top'
#)
title = f'{country_name} {season_name}-{product_name_fdw}-Production'# and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()
# ---------------------------------------------------- #

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load Crop Data ------------------------------------- #
country_name, season_name, product_name_fdw, product_name_fao,  = 'Mozambique', 'Main', 'Millet', 'Millet'
shape_code, prcp_start_month, prcp_season_name, prcp_year_offset = 'MZ2013A0', 10, 'OND PRCP (mm)', +1
# HarvestStat
df = pd.read_csv('../public/hvstat_data.csv', index_col=0)
df = df[
    (df['country'] == country_name) &
    (df['season_name'] == season_name) &
    (df['product'].isin([product_name_fdw])) &
    (df['indicator'] == 'production')
].copy()
df['year'] = df['harvest_year']
data_hs = df.pivot_table(index='year',columns='product',values='value',aggfunc='sum').squeeze()
# FAO-STAT
df = pd.read_csv('../data/crop/adm_fao_stat.csv', index_col=0)
data_fao = df[
    (df['Area'] == country_name) &
    (df['Item'] == product_name_fao) &
    (df['Element'] == 'Production')
].set_index('Year')['Value']
# Merge
data = pd.concat([data_fao,data_hs], axis=1, keys=['FAO','HS']).sort_index()
data = data.reindex(np.array(range(1982,2024)))
# ---------------------------------------------------- #
fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
data.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
title = f'{country_name} {season_name}-{product_name_fdw}-Production'# and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()
# ---------------------------------------------------- #

# %%
df = pd.read_csv('../public/hvstat_data.csv', index_col=0)
df['product'].unique()
# Out:
# array(['Cassava', 'Maize', 'Potato', 'Sweet Potatoes', 'Beans',
#        'Groundnuts', 'Pineapple', 'Banana', 'Sorghum', 'Onions', 'Tomato',
#        'Lemon', 'Mango', 'Millet', 'Garlic', 'Soybean', 'Rice', 'Cabbage',
#        'Carrots', 'Avocado', 'Wheat', 'Cowpeas', 'Okras', 'Green bean',
#        'Cocoyam', 'Gram', 'Pigeon Peas', 'Barley', 'Yams',
#        'Groundnuts (In Shell)', 'Sesame Seed', 'Bambara groundnut',
#        'Cowpea', 'Sorghum (Red)', 'Fonio', 'Pea', 'Oats', 'Sugarcane',
#        'Rice (Paddy)', 'Beans (mixed)', 'Millet (Finger)',
#        'Potato (Irish)', 'Sunflower Seed', 'Pigeon pea (Unspecified)',
#        'Bean (Hyacinth)', 'Millet (Pearl)', 'Tangerine', 'Field Peas',
#        'Beans (Pinto)', 'Chick Peas', 'Cowpeas (Mixed)', 'Velvet bean',
#        'Spanish peanut', 'Sweet Potatoes (Orange)', 'Virginia peanut',
#        'Beans (Lima)', 'Sweet Potatoes (Non-Orange)',
#        'Groundnuts (In Shell, Large)', 'Groundnuts (In Shell, Small)',
#        'Canola seed', 'Cottonseed', 'Sunflower seed', 'Groundnut'],
#       dtype=object)
