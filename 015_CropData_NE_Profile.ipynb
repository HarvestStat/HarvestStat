# %% [markdown]
# ## FDW Crop Production Data Profiling - Niger

# %%
import os, sys, glob, json
from itertools import product, compress, chain
from functools import reduce
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import requests
import numpy as np
import pandas as pd
import geopandas as gpd
from tools import save_hdf, save_npz, load_npz, PrintAdminUnits, PlotAdminShapes
from tools import FDW_PD_Sweeper, FDW_PD_AvalTable, FDW_PD_Compiling, FDW_PD_GrainTypeAgg, FDW_PD_ValidateFnidName
from tools import FDW_PD_CreateAdminLink, FDW_PD_RatioAdminLink, FDW_PD_ConnectAdminLink
from tools import FDW_PD_CaliSeasonYear
from tools_graphic import PlotBarProduction, PlotLinePAY, PlotHeatCropSystem, PlotHeatSeasonData
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

# %%
# CPCV2 grain code ------------------------------ #
grain_code = pd.read_hdf('./data/crop/grain_cpcv2_code.hdf')
product_category = grain_code[['product', 'product_category']].set_index('product').to_dict()['product_category']
# ----------------------------------------------- #

# Load FEWS NET administrative boundaries ------- #
epsg = 'EPSG:32631'
fn_shapes = sorted(glob.glob('./data/shapefile/fewsnet/NE_Admin?_????.shp'))
shape_all = []
for fn in fn_shapes:
    name = fn[-18:-4]
    exec('%s = gpd.read_file("%s").to_crs("%s")' % (name, fn, epsg))
    exec('%s["area"] = %s["geometry"].area/10**6' % (name, name))
    exec('shape_all.append(%s)' % (name))
shape_all = pd.concat(shape_all, axis=0).reset_index(drop=True)
PrintAdminUnits(shape_all)
# ----------------------------------------------- #

# FDW API host address -------------------------- #
host = 'https://fdw.fews.net'
#read in username and password
auth = tuple(json.loads(open('token.json', "r").read()))
parameters = {
    'format': 'json',
    'country': 'Niger',
    'product': 'R011',
    'survey_type': 'crop:best'
}
endpoint = '/api/cropproductionindicatorvalue/'
response = requests.get(host + endpoint, auth=auth, params=parameters, proxies={})
response.raise_for_status()
df = pd.DataFrame.from_records(response.json())
df_origin = df.copy()
# ----------------------------------------------- #
# Out:
# - FEWS NET admin shapefiles ------------------- #
# | year	 | Admin1   | # units   | Admin2   | # units   | Admin3   | # units   |
# | 1972	 | NE1972A1 | 7	| NE1972A2	| 35	| nan	| 0	|
# | 1992	 | NE1992A1 | 8	| NE1992A2	| 36	| nan	| 0	|
# | 2001	 | NE2001A1 | 8	| NE2001A2	| 37	| nan	| 0	|
# | 2012	 | NE2012A1 | 8	| NE2012A2	| 74	| nan	| 0	|
# | 2018	 | NE2018A1 | 8	| NE2018A2	| 67	| nan	| 0	|
# ----------------------------------------------- #

# %%
# Manual Pre-processing before Sweeping --------- #
# 1. Default setting 
# a) None-type crop production system
df.loc[df['crop_production_system'].isna(), 'crop_production_system'] = 'none'
df.loc[df['crop_production_system'] == '', 'crop_production_system'] = 'none'
# b) None-type population group
df.loc[df['population_group'].isna(), 'population_group'] = 'none'
df.loc[df['population_group'] == '', 'population_group'] = 'none'

# FDW Production Data Inspection ---------------- #
df, df_raw = FDW_PD_Sweeper(df)
table_dict = FDW_PD_AvalTable(df, shape_all)
# ----------------------------------------------- #

# FEWS NET Shapefile comparison ----------------- #
shape_used = pd.concat([NE_Admin2_1972,NE_Admin2_1992,NE_Admin2_2001,NE_Admin2_2012,NE_Admin2_2018], axis=0)
PlotAdminShapes(shape_used, label=True)
# ----------------------------------------------- #
# Out:
# - Remove missing records ---------------------- #
# Orignial data points: 12,243
# Removed 884 "Missing Value" points
# 3,811/3,837 "Area Planted" points are retained.
# 3,774/3,837 "Quantity Produced" points are retained.
# 3,774/3,837 "Yield" points are retained.
# 0/732 "Area Harvested" points are retained.
# Current data points: 11,359
#
# - Minor changes are applied ------------------- #
#
# - Basic information --------------------------- #
# Data period: 1980 - 2021
# 5 grain types are found: Fonio, Maize (Corn), Millet, Rice (Paddy), Sorghum
# 1 seasons are found: Main season (06-01)
# 1 crop production system are found: none
# Data sources include:
# [1] Ministere de l'Agriculture, Niger --- FEWS NET Agro Maps, Niger
# [2] Ministere de l'Agriculture, Niger --- Official agricultural statistics, Niger
# [3] Ministere de l'Agriculture, Niger --- Resultats definitifs campagne agricole, Niger
# Administrative-1 fnids: 0
# Administrative-2 fnids: 175
# 0 reporting units are found:
#
# - Total production over time ------------------ #
# season_name  Main season
#
# Fonio               0.1%
# Maize (Corn)        0.1%
# Millet             74.1%
# Rice (Paddy)        0.5%
# Sorghum            25.2%
#
# - Crop calendar ------------------------------- #
#         product  season_name planting_month harvest_month
# 0         Fonio  Main season          06-01         12-01
# 1         Fonio  Main season          06-01         10-01
# 2  Maize (Corn)  Main season          06-01         12-01
# 3  Maize (Corn)  Main season          06-01         10-01
# 4        Millet  Main season          06-01         12-01
# 5        Millet  Main season          06-01         10-01
# 6  Rice (Paddy)  Main season          06-01         12-01
# 7  Rice (Paddy)  Main season          06-01         10-01
# 8       Sorghum  Main season          06-01         12-01
# 9       Sorghum  Main season          06-01         10-01
#
# - Recorded years per season ------------------- #
# Main season: 42 years (1980-2021) (missing: 2 years)
#
# - Number of "Quantity Produced" data points --- #
# NE1972A2: 912 data points are found.
# NE1992A2: 714 data points are found.
# NE2001A2: 807 data points are found.
# NE2012A2: 1,341 data points are found.
#
# - Districts with population group(s) ---------- #
# 0 districts includes 'population_group'.
#
# Table of available data
# ----------------------------------------------- #
# Crop type: Fonio
# ----------------------------------------------- #
# season_name            Main season
# crop_production_system        none
# fnid_short                  2001A2 2012A2
# year
# 2002                          3/37    NaN
# 2003                          2/37    NaN
# 2004                          3/37    NaN
# 2005                          1/37    NaN
# 2006                          4/37    NaN
# 2007                          3/37    NaN
# 2008                          2/37    NaN
# 2009                          1/37    NaN
# 2010                          3/37    NaN
# 2011                          2/37    NaN
# 2012                           NaN   4/74
# 2013                           NaN   4/74
# 2014                           NaN   5/74
# 2015                           NaN   5/74
# 2016                           NaN   8/74
# 2017                           NaN    NaN
# 2018                           NaN    NaN
# 2019                           NaN   7/74
# 2020                           NaN   7/74
# 2021                           NaN   6/74
# ----------------------------------------------- #
# Crop type: Maize (Corn)
# ----------------------------------------------- #
# season_name            Main season
# crop_production_system        none
# fnid_short                  1972A2 1992A2 2001A2 2012A2
# year
# 1980                         11/35    NaN    NaN    NaN
# 1981                          9/35    NaN    NaN    NaN
# 1982                         11/35    NaN    NaN    NaN
# 1983                          8/35    NaN    NaN    NaN
# 1984                          6/35    NaN    NaN    NaN
# 1985                          7/35    NaN    NaN    NaN
# 1986                          6/35    NaN    NaN    NaN
# 1987                          6/35    NaN    NaN    NaN
# 1995                           NaN  32/36    NaN    NaN
# 1996                           NaN  32/36    NaN    NaN
# 1997                           NaN  32/36    NaN    NaN
# 1998                           NaN  32/36    NaN    NaN
# 1999                           NaN  32/36    NaN    NaN
# 2000                           NaN  31/36    NaN    NaN
# 2001                           NaN  31/36    NaN    NaN
# 2002                           NaN    NaN  33/37    NaN
# 2003                           NaN    NaN  28/37    NaN
# 2004                           NaN    NaN  34/37    NaN
# 2005                           NaN    NaN  33/37    NaN
# 2006                           NaN    NaN  34/37    NaN
# 2007                           NaN    NaN  34/37    NaN
# 2008                           NaN    NaN  34/37    NaN
# 2009                           NaN    NaN  34/37    NaN
# 2010                           NaN    NaN  33/37    NaN
# 2011                           NaN    NaN  34/37    NaN
# 2012                           NaN    NaN    NaN  64/74
# 2013                           NaN    NaN    NaN  65/74
# 2014                           NaN    NaN    NaN  67/74
# 2015                           NaN    NaN    NaN  64/74
# 2016                           NaN    NaN    NaN  68/74
# 2017                           NaN    NaN    NaN    NaN
# 2018                           NaN    NaN    NaN    NaN
# 2019                           NaN    NaN    NaN  64/74
# 2020                           NaN    NaN    NaN  65/74
# 2021                           NaN    NaN    NaN  65/74
# ----------------------------------------------- #
# ./figures/NE_admin_shapes.png is saved.

# %% [markdown]
# ## Niger
# Niger crop seasonal calendar
#
# ![FEWS NET](https://fews.net/sites/default/files/styles/large_width_880/public/2023-03/seasonal-calendar-niger.png?itok=UBgvvRXP)
#
# ![USDA](https://ipad.fas.usda.gov/rssiws/al/crop_calendar/images/wafrica_ng_calendar.png)
#
# - comparison of boundaries
# ![image](./figures/NE_admin_shapes.png)
#
# - In Niger, basd on the FEWS NET data, there were four times of changes in administrative units: 1972, 1992, 2012, and 2018.
#
# | year	 | Admin1   | # units   | Admin2   | # units   |
# | :---: | :----:  | :----:   | :----:   | :---:  |
# | 1972	 | NE1972A1 | 7	| NE1972A2	| 35	|
# | 1992	 | NE1992A1 | 8	| NE1992A2	| 36	|
# | 2001	 | NE2001A1 | 8	| NE2001A2	| 37	|
# | 2012	 | NE2012A1 | 8	| NE2012A2	| 74	|
# | 2018	 | NE2018A1 | 8	| NE2018A2	| 67	|
#
# - The data is all reported in a single main season
# - While there is a shapefile for 2018, there is no crop data associated with the 2018 shapefile, so we use 2012 as the most recent shapefile

# %%
# Define the latest shapefile ------------------- #
latest_level = 2
shape_latest = NE_Admin2_2012.copy().to_crs('epsg:32631')
# ----------------------------------------------- #

# Validation of FNIDs and Names ----------------- #
df = FDW_PD_ValidateFnidName(df, shape_used, shape_latest)
# ----------------------------------------------- #

# FDW Production Data Compiling ----------------- #
area, prod = FDW_PD_Compiling(df, shape_used)
area_all, prod_all = area.copy(), prod.copy()
mdx_pss = area.columns.droplevel([0,1]).unique()
# ----------------------------------------------- #
# Out:
# NE2001A20704:	"Matameye" (FDW) is changed to "Kantche" (shapefile).
# NE2012A20311:	"Dioundiou" (FDW) is changed to "Dioudiou" (shapefile).
# NE2012A20109:	"Agadez Commune" (FDW) is changed to "Tchirozerine" (shapefile).

# %%
# Link admin boundaries ------------------------- #
link_2001, over_2001 = FDW_PD_CreateAdminLink(NE_Admin2_2001, NE_Admin2_2012, 'ADMIN2', 'ADMIN2', prod, epsg)
#assert all(np.unique([v['method'] for k,v in link_2001.items()]) == 'PBR')
link_1992, over_1992 = FDW_PD_CreateAdminLink(NE_Admin2_1992, NE_Admin2_2012, 'ADMIN2', 'ADMIN2', prod, epsg)
#assert all(np.unique([v['method'] for k,v in link_1992.items()]) == 'PBR')
link_1972, over_1972 = FDW_PD_CreateAdminLink(NE_Admin2_1972, NE_Admin2_2012, 'ADMIN2', 'ADMIN2', prod, epsg)
#assert all(np.unique([v['method'] for k,v in link_1972.items()]) == 'PBR')


# Crop specific ratios
link_ratio_1972 = FDW_PD_RatioAdminLink(link_1972, prod, over_1972, mdx_pss)
link_ratio_1992 = FDW_PD_RatioAdminLink(link_1992, prod, over_1992, mdx_pss)
link_ratio_2001 = FDW_PD_RatioAdminLink(link_2001, prod, over_2001, mdx_pss)

# Merge link_ratio
assert link_ratio_1992.keys() == link_ratio_2001.keys()
assert link_ratio_1972.keys() == link_ratio_2001.keys()

link_merged = [link_ratio_1972, link_ratio_1992, link_ratio_2001]
fnids_new = list(link_merged[0].keys())
link_ratio = dict()
for fnid in fnids_new:
    container = []
    for link in link_merged:
        container.append(link[fnid])
    link_ratio[fnid] = pd.concat(container, axis=1)
# Add current unit to link_ratio
for fnid_new in link_ratio.keys():
    link_ratio[fnid_new][fnid_new] = 1.0
    link_ratio[fnid_new] = link_ratio[fnid_new].sort_index(axis=1, ascending=False)
# Connect data with AdminLink
area_new, prod_new = FDW_PD_ConnectAdminLink(link_ratio, area, prod, validation=False)
# ----------------------------------------------- #
# Out:
# CBR is considered for 'NE2001A20103' as no record found in: ['NE2012A20103']
# CBR is considered for 'NE2001A20203' as no record found in: ['NE2012A20209']
# CBR is considered for 'NE2001A20702' as no record found in: ['NE2012A20707']
# CBR is considered for 'NE1992A20103' as no record found in: ['NE2012A20103']
# CBR is considered for 'NE1992A20203' as no record found in: ['NE2012A20209']
# CBR is considered for 'NE1992A20702' as no record found in: ['NE2012A20707']
# CBR is considered for 'NE1972A20702' as no record found in: ['NE2012A20707']
# CBR is considered for 'NE1972A20203' as no record found in: ['NE2012A20209']
# CBR is considered for 'NE1972A20103' as no record found in: ['NE2012A20103']

# %%
# Manual correction ----------------------------- #
crop_new = prod_new/area_new
#I need to be able to look at the source docs here. I think maize planted area was used
#area_new.loc[2019,pd.IndexSlice['NE2012A20804',:,'Millet','Main season',:,:,'none']] = 2000
#area_new.loc[2019,pd.IndexSlice['NE2012A20805',:,'Millet','Main season',:,:,'none']] = 4000

# Complete long format DataFrame ---------------- #
df_area = area_new.T.stack().rename('value').reset_index()
df_area['indicator'] = 'area'
df_prod = prod_new.T.stack().rename('value').reset_index()
df_prod['indicator'] = 'production'
df_yield = (prod_new/area_new).T.stack().rename('value').reset_index()
df_yield['indicator'] = 'yield'
stack = pd.concat([df_area, df_prod, df_yield], axis=0)
# Add "planting year"
cols = ['season_name','product','crop_production_system','planting_month','harvest_year','harvest_month','planting_year']
season_table = df[cols].drop_duplicates()
stack = stack.merge(season_table, on=cols[:-1])
# Add country and admin names
stack = stack.merge(df[['fnid','country','country_code','admin_1','admin_2']].drop_duplicates(), on='fnid', how='inner')
names = [
    'fnid','country','country_code','admin_1','admin_2','name',
    'product','season_name','planting_year','planting_month','harvest_year','harvest_month',
    'crop_production_system','indicator','value'
]
stack_gscd = stack[names]
stack_gscd['gscd_code'] = 'calibrated'
# ----------------------------------------------- #

# Reported FDW data ----------------------------- #
stack_fdw = df[names]
stack_fdw['indicator'] = stack_fdw['indicator'].replace({'Area Harvested':'area','Quantity Produced':'production','Yield':'yield'})
stack_fdw['gscd_code'] = 'reported'
# ----------------------------------------------- #

# Final Processing ------------------------------ #
stack = pd.concat([stack_fdw,stack_gscd], axis=0).reset_index(drop=True)
# No concerns found for grain types
stack['product'] = stack['product'].replace(product_category)
# Calibration of planting and Harvest year and season
cs = {
    'Main season': {'planting_month':{'06-01':'06-01'},'harvest_month':{'12-01':'10-01'}},
}
cy = {}
stack, df, link_ratio = FDW_PD_CaliSeasonYear(stack, df, link_ratio, cs, cy)
stack.loc[stack['admin_1'].isna(), 'admin_1'] = 'none'
stack.loc[stack['admin_2'].isna(), 'admin_2'] = 'none'
# # ----------------------------------------------- #

# Save data
fn_out = './data/crop/adm_crop_production_NE.csv'
stack.to_csv(fn_out); print(f'{fn_out} is saved.')
save_hdf('./data/crop/adm_crop_production_NE.hdf', stack)
save_hdf('./data/crop/adm_crop_production_NE_raw.hdf', df)
save_npz('./data/crop/adm_crop_production_NE_ratio.npz', link_ratio)
# Out:
# ./data/crop/adm_crop_production_NE.csv is saved.
# ./data/crop/adm_crop_production_NE.hdf is saved.
# ./data/crop/adm_crop_production_NE_raw.hdf is saved.
# ./data/crop/adm_crop_production_NE_ratio.npz is saved.

# %% [markdown]
# ## Visualization of production data

# %%
# Bar chart of national grain production
country_iso, country_name = 'NE', 'Niger'
df = pd.read_hdf('./data/crop/adm_crop_production_%s.hdf' % country_iso)
df = df[df['gscd_code']=='calibrated']; df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_order = ['Maize', 'Fonio','Millet', 'Rice','Sorghum']
for season_name in ['Main season']:
    footnote = 'National grain production in %s - %s' % (country_name, season_name)
    fn_save = './figures/%s_bar_natgrainprod_%s.png' % (country_iso, season_name)
    sub = df[df['season_name'] == season_name]
    fig = PlotBarProduction(sub, year, product_order, footnote, fn_save)
    fig.show()
# Out:
# ./figures/NE_bar_natgrainprod_Main season.png is saved.

# %%
# Lineplot of Production-Area-Yield (PAY) time-series
country_iso, country_name = 'NE', 'Niger'
df = pd.read_hdf('./data/crop/adm_crop_production_%s.hdf' % country_iso)
df = df[df['gscd_code']=='calibrated']; df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_season = [
    ['Millet','Main season'],
    ['Sorghum','Main season'],
    ['Maize','Main season'],
    ['Rice','Main season'],
    ['Fonio','Main season'],
]
for product_name, season_name in product_season:
    footnote = 'Production-Area-Yield (PAY) time-series of %s - %s - %s' % (country_iso, product_name, season_name)
    fn_save = './figures/%s_line_pay_%s_%s.png' % (country_iso, product_name, season_name)
    sub = df[(df['product'] == product_name) & (df['season_name'] == season_name)]
    fig = PlotLinePAY(sub, year, footnote, fn_save)
    fig.show()
# Out:
# ./figures/NE_line_pay_Millet_Main season.png is saved.
# ./figures/NE_line_pay_Sorghum_Main season.png is saved.
# ./figures/NE_line_pay_Maize_Main season.png is saved.
# ./figures/NE_line_pay_Rice_Main season.png is saved.
# ./figures/NE_line_pay_Fonio_Main season.png is saved.

# %%
# Calibrated PAY time-series per FNID
from tools_graphic import PlotLineCropTS
country_iso, country_name = 'NE', 'Niger'
df = pd.read_hdf('./data/crop/adm_crop_production_%s.hdf' % country_iso)
df = df[df['gscd_code']=='calibrated']; df['year'] = df['harvest_year']
link_ratio = load_npz('./data/crop/adm_crop_production_%s_ratio.npz' % country_iso)
year_all = np.arange(df['year'].min(), df['year'].max()+1)
product_season = [
    ['Millet','Main season'],
    ['Sorghum','Main season'],
    ['Maize','Main season'],
    ['Rice','Main season'],
    ['Fonio','Main season'],
]
for product_name, season_name in product_season:
    sub = df[
        (df['product'] == product_name) &
        (df['season_name'] == season_name)
    ]
    for fnid in sub['fnid'].unique():
        sub_fps = sub[sub['fnid'] == fnid]
        fn_save = './figures/crop_calibrated/%s_%s_%s_%s.png' % (country_iso, product_name, season_name, fnid)
        fig = PlotLineCropTS(sub_fps, fnid, product_name, season_name, link_ratio, year_all, fn_save)
# Out:
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20104.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20106.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20108.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20109.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20204.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20205.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20206.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20207.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20208.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20210.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20305.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20306.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20307.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20308.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20309.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20310.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20311.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20312.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20313.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20401.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20404.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20405.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20406.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20407.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20408.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20409.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20410.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20504.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20507.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20509.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20510.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20511.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20512.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20513.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20514.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20515.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20516.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20517.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20519.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20520.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20603.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20607.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20608.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20609.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20610.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20611.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20612.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20613.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20614.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20615.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20616.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20617.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20618.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20619.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20704.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20706.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20708.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20709.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20710.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20711.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20712.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20713.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20714.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20715.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20802.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20803.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20804.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20805.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20806.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20105.png is saved.
# ./figures/crop_calibrated/NE_Millet_Main season_NE2012A20107.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20104.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20106.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20108.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20109.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20204.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20205.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20206.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20207.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20208.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20210.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20305.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20306.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20307.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20308.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20309.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20310.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20311.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20312.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20313.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20401.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20404.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20405.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20406.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20407.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20408.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20409.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20410.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20504.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20507.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20509.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20510.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20511.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20512.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20513.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20514.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20515.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20516.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20517.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20519.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20520.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20603.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20607.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20608.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20609.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20610.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20611.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20612.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20613.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20614.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20615.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20616.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20617.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20618.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20619.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20704.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20706.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20708.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20709.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20710.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20711.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20712.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20713.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20714.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20715.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20802.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20803.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20804.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20805.png is saved.
# ./figures/crop_calibrated/NE_Sorghum_Main season_NE2012A20806.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20104.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20106.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20108.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20109.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20204.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20205.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20210.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20305.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20307.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20308.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20309.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20310.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20311.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20312.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20401.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20406.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20407.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20408.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20410.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20504.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20507.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20509.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20512.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20515.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20516.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20517.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20519.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20603.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20607.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20611.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20612.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20613.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20614.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20616.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20710.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20711.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20712.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20715.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20805.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20806.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20105.png is saved.
# ./figures/crop_calibrated/NE_Maize_Main season_NE2012A20107.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20204.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20205.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20210.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20305.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20306.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20307.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20310.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20311.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20312.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20603.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20612.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20617.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20618.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20619.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20708.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20709.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20802.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20803.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20804.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20805.png is saved.
# ./figures/crop_calibrated/NE_Rice_Main season_NE2012A20806.png is saved.
# ./figures/crop_calibrated/NE_Fonio_Main season_NE2012A20308.png is saved.
# ./figures/crop_calibrated/NE_Fonio_Main season_NE2012A20309.png is saved.
# ./figures/crop_calibrated/NE_Fonio_Main season_NE2012A20310.png is saved.
# ./figures/crop_calibrated/NE_Fonio_Main season_NE2012A20311.png is saved.
# ./figures/crop_calibrated/NE_Fonio_Main season_NE2012A20312.png is saved.
# ./figures/crop_calibrated/NE_Fonio_Main season_NE2012A20406.png is saved.
# ./figures/crop_calibrated/NE_Fonio_Main season_NE2012A20610.png is saved.
# ./figures/crop_calibrated/NE_Fonio_Main season_NE2012A20614.png is saved.
# ./figures/crop_calibrated/NE_Fonio_Main season_NE2012A20615.png is saved.

# %%
# # Heatmap of seasonal data availability
# country_iso, country_name = 'NE', 'Niger'
# df = pd.read_hdf('./data/crop/adm_crop_production_%s_raw.hdf' % country_iso)
# df['year'] = df['harvest_year']
# code = {'Main season':1}
# comb = {1:1,10:2,11:3}
# comb_name = {1:'Main season'}
# for product_name in ['Sorghum','Millet','Maize (Corn)']:
#     fig = plt.figure()
#     data = df[(df['product'] == product_name) & (df['season_name'].isin(code.keys()))]
#     footnote = 'Seasonal data availability in %s - %s (uncorrected)' % (country_name, product_name)
#     fn_save = './figures/%s_heat_seasondata_%s.png' % (country_iso, product_name)
#     fig = PlotHeatSeasonData(data, code, comb, comb_name, footnote, fn_save)
