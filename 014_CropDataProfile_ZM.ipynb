# %% [markdown]
# ## FDW Crop Production Data Profiling - Zambia

# %%
import os, sys, glob, json
from itertools import product, compress, chain
from functools import reduce
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import requests
import numpy as np
import pandas as pd
import geopandas as gpd
from tools import save_hdf, save_npz, load_npz, PrintAdminUnits, PlotAdminShapes
from tools import FDW_PD_Sweeper, FDW_PD_AvalTable, FDW_PD_Compiling, FDW_PD_GrainTypeAgg, FDW_PD_ValidateFnidName
from tools import FDW_PD_CreateAdminLink, FDW_PD_RatioAdminLink, FDW_PD_ConnectAdminLink
from tools import FDW_PD_CaliSeasonYear
from tools_graphic import PlotBarProduction, PlotLinePAY, PlotHeatCropSystem, PlotHeatSeasonData
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

# %%
# CPCV2 grain code ------------------------------ #
grain_code = pd.read_hdf('./data/crop/grain_cpcv2_code.hdf')
product_category = grain_code[['product', 'product_category']].set_index('product').to_dict()['product_category']
# ----------------------------------------------- #

# Load FEWS NET administrative boundaries ------- #
epsg = 'EPSG:22234' 
fn_shapes = sorted(glob.glob('./data/shapefile/fewsnet/ZM_Admin?_????.shp'))
shape_all = []
for fn in fn_shapes:
    name = fn[-18:-4]
    exec('%s = gpd.read_file("%s").to_crs("%s")' % (name, fn, epsg))
    exec('%s["area"] = %s["geometry"].area/10**6' % (name, name))
    exec('shape_all.append(%s)' % (name))
shape_all = pd.concat(shape_all, axis=0).reset_index(drop=True)
PrintAdminUnits(shape_all)
# ----------------------------------------------- #

# FDW API host address -------------------------- #
host = 'https://fdw.fews.net'
#read in username and password
exec(open('/Users/wanders7/Documents/Code/Logins/FDW.py').read())
auth = (username, password)
parameters = {
    'format': 'json',
    'country': 'Zambia',
    'product': 'R011',
    'survey_type': 'crop:best'
}
endpoint = '/api/cropproductionindicatorvalue/'
response = requests.get(host + endpoint, auth=auth, params=parameters, proxies={})
response.raise_for_status()
df = pd.DataFrame.from_records(response.json())
df_origin = df.copy()
# ----------------------------------------------- #
# Out:
# - FEWS NET admin shapefiles ------------------- #
# | year	 | Admin1   | # units   | Admin2   | # units   |
# | 1980	 | ZM1980A1 | 9	| ZM1980A2	| 57	|
# | 1990	 | ZM1990A1 | 9	| nan	| 0	|
# | 1998	 | nan | 0	| ZM1998A2	| 72	|
# | 2011	 | ZM2011A1 | 10	| ZM2011A2	| 74	|
# | 2012	 | ZM2012A1 | 10	| ZM2012A2	| 89	|
# ----------------------------------------------- #

# %%
# Manual Pre-processing before Sweeping --------- #
# 1. Default setting 
# a.1) None-type crop production system
df.loc[df['crop_production_system'].isna(), 'crop_production_system'] = 'none'
df.loc[df['crop_production_system'] == '', 'crop_production_system'] = 'none'
# a.2) Early in the record the catch-all crop production system is 'all' rather than none. Make these to none-type
df.loc[df['crop_production_system'] == 'all', 'crop_production_system'] = 'none'
# b) None-type population group
df.loc[df['population_group'].isna(), 'population_group'] = 'none'
df.loc[df['population_group'] == '', 'population_group'] = 'none'


#2. Manual setting
# a) population groups within admin units
# Zambia has a number of admin 2 units with population groups that split the admin into two, 
# (e.g. ~Lusaka Rural East~ and ~Lusaka Rural West~). These two groups need to be recombined to map because
# there is no regional shapefile definition for these sub-admin units (for some countries there is)
#
# Calculate the sum of production, harvested area and planted area, then recalculate yield for these admin units
rows = ['fnid','season_year', 'product','indicator','crop_production_system','value','population_group']
#find duplicates then aggregate to fnid after pivoting around the indicator
dupes = df[rows[:-1]][df[rows[:-2]].duplicated(keep=False)]
#create a df that has one value per duplicated value
toFill = df[df[['fnid','season_year','indicator','crop_production_system','product']].duplicated(keep=False)]# find all duplicates
toFill = toFill[~toFill[['fnid','season_year','indicator','crop_production_system','product']].duplicated(keep='first')]# keep only one
dupes = dupes.groupby(by=['fnid','season_year','indicator','crop_production_system','product']).sum()
dupes.reset_index(inplace=True)
d_ha = dupes.copy(deep=True)
d_pa = dupes.copy(deep=True)
d_ha['value'].loc[dupes.indicator=='Yield'] = d_ha['value'].loc[d_ha.indicator=='Quantity Produced'].values/\
                                               d_ha['value'].loc[d_ha.indicator=='Area Harvested'].values
#if calculated yield is nan (meaning HA = 0), recalculate w/ planted area
d_pa['value'].loc[dupes.indicator=='Yield'] = d_pa['value'].loc[d_pa.indicator=='Quantity Produced'].values/\
                                               d_pa['value'].loc[d_pa.indicator=='Area Planted'].values
dupes['value'].loc[dupes.indicator=='Yield'] = d_ha['value'].loc[dupes.indicator=='Yield']
#find where calculated yield is nan when calculated with HA and use PA instead
dupes['value'].loc[(dupes.indicator=='Yield')&(~np.isfinite(dupes.value))] = \
      d_pa['value'].loc[(dupes.indicator=='Yield')&(~np.isfinite(dupes.value))]
#set 0 back to nan
dupes['value'].loc[dupes.value==0]=np.nan
#merge the new values back into the placeholder DF
toFill = toFill.drop(['value'],axis=1)
toFill = toFill.merge(dupes, how='left',on = ['fnid','season_year','indicator','crop_production_system','product'])
#drop all duplicate obs from original DF and append the filled DF
df = df[~df[['fnid','season_year','indicator','crop_production_system','product']].duplicated(keep=False)]
df = df.append(toFill)


#3) limit to areas with collected data
df = df[df['status'] == 'Collected']

# FDW Production Data Inspection ---------------- #
df, df_raw = FDW_PD_Sweeper(df)
table_dict = FDW_PD_AvalTable(df, shape_all)
# ----------------------------------------------- #

# FEWS NET Shapefile comparison ----------------- #
shape_used = pd.concat([ZM_Admin2_1980,ZM_Admin2_1998,ZM_Admin2_2011,ZM_Admin2_2012], axis=0)
PlotAdminShapes(shape_used, label=True)
# ----------------------------------------------- #
# Out:
# /var/folders/pk/_ym78shs7tx06w00zbcwxwgc0000gp/T/ipykernel_51541/3381260553.py:30: RuntimeWarning: divide by zero encountered in true_divide
#   d_ha['value'].loc[dupes.indicator=='Yield'] = d_ha['value'].loc[d_ha.indicator=='Quantity Produced'].values/\
# - Remove missing records ---------------------- #
# Orignial data points: 20,852
# Removed 196 "Missing Value" points
# 3,660/3,691 "Area Harvested" points are retained.
# 5,706/5,731 "Area Planted" points are retained.
# 5,646/5,715 "Quantity Produced" points are retained.
# 5,644/5,715 "Yield" points are retained.
# Current data points: 20,656
#
# - Minor changes are applied ------------------- #
#
# - Basic information --------------------------- #
# Data period: 1980 - 2017
# 9 grain types are found: Barley (Unspecified), Maize (Corn), Maize Grain (White), Maize Grain (Yellow), Millet, Millet (Finger), Rice (Paddy), Sorghum, Wheat Grain
# 1 seasons are found: Annual (04-01)
# 1 crop production system are found: none
# Data sources include:
# [1] Ministry of Agriculture and The Central Statistics Office, Zambia --- Crop Forecast Survey Results, Zambia
# [2] Ministry of Agriculture and The Central Statistics Office, Zambia --- FEWS NET Agro Maps, Zambia
# Administrative-1 fnids: 0
# Administrative-2 fnids: 202
# 0 reporting units are found:
#
# - Total production over time ------------------ #
# season_name          Annual
#
# Barley (Unspecified)   0.1%
# Maize (Corn)          47.8%
# Maize Grain (White)   44.6%
# Maize Grain (Yellow)   0.0%
# Millet                 1.6%
# Millet (Finger)        0.1%
# Rice (Paddy)           1.0%
# Sorghum                0.8%
# Wheat Grain            4.0%
#
# - Crop calendar ------------------------------- #
#                 product season_name growing_month harvest_month
# 0  Barley (Unspecified)      Annual         04-01         07-01
# 1          Maize (Corn)      Annual         04-01         07-01
# 2   Maize Grain (White)      Annual         04-01         07-01
# 3  Maize Grain (Yellow)      Annual         04-01         07-01
# 4                Millet      Annual         04-01         07-01
# 5       Millet (Finger)      Annual         04-01         07-01
# 6          Rice (Paddy)      Annual         04-01         07-01
# 7               Sorghum      Annual         04-01         07-01
# 8           Wheat Grain      Annual         04-01         07-01
#
# - Recorded years per season ------------------- #
# Annual: 38 years (1980-2017) (missing: 4 years)
#
# - Number of "Quantity Produced" data points --- #
# ZM1980A2: 1,406 data points are found.
# ZM1998A2: 2,840 data points are found.
# ZM2011A2: 1,425 data points are found.
#
# - Districts with population group(s) ---------- #
# 4 districts includes 'population_group'.
# : ZM1980A20516, ZM1980A21114, ZM1980A21115, ZM1980A21218
#
# Table of available data
# ----------------------------------------------- #
# Crop type: Barley (Unspecified)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             1998A2 2011A2
# year
# 2011                     5/72    NaN
# 2012                      NaN   9/74
# 2013                      NaN   6/74
# 2014                      NaN   7/74
# 2015                      NaN   3/74
# 2016                      NaN   5/74
# ----------------------------------------------- #
# Crop type: Maize (Corn)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             1980A2 1998A2 2011A2
# year
# 1980                    50/57   1/72    NaN
# 1981                    52/57   1/72    NaN
# 1982                    53/57   1/72    NaN
# 1983                    54/57   1/72    NaN
# 1984                    52/57   1/72    NaN
# 1985                    52/57   1/72    NaN
# 1986                    52/57   1/72    NaN
# 1987                    54/57   1/72    NaN
# 1988                    52/57   1/72    NaN
# 1989                    54/57   1/72    NaN
# 1990                    53/57   1/72    NaN
# 1991                    54/57   1/72    NaN
# 1992                    55/57   1/72    NaN
# 1993                    56/57   1/72    NaN
# 1994                      NaN    NaN    NaN
# 1995                      NaN    NaN    NaN
# 1996                      NaN    NaN    NaN
# 1997                    54/57   1/72    NaN
# 1998                      NaN  70/72    NaN
# 1999                      NaN  69/72    NaN
# 2000                      NaN    NaN    NaN
# 2001                      NaN  71/72    NaN
# 2002                      NaN  71/72    NaN
# 2003                      NaN  72/72    NaN
# 2004                      NaN    NaN    NaN
# 2005                      NaN    NaN    NaN
# 2006                      NaN    NaN    NaN
# 2007                      NaN    NaN    NaN
# 2008                      NaN    NaN    NaN
# 2009                      NaN    NaN    NaN
# 2010                      NaN    NaN    NaN
# 2011                      NaN    NaN    NaN
# 2012                      NaN    NaN    NaN
# 2013                      NaN    NaN  74/74
# 2014                      NaN    NaN  74/74
# ----------------------------------------------- #
# Crop type: Maize Grain (White)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             1998A2 2011A2
# year
# 1999                     1/72    NaN
# 2000                      NaN    NaN
# 2001                      NaN    NaN
# 2002                      NaN    NaN
# 2003                      NaN    NaN
# 2004                    72/72    NaN
# 2005                    72/72    NaN
# 2006                    72/72    NaN
# 2007                    72/72    NaN
# 2008                    72/72    NaN
# 2009                    72/72    NaN
# 2010                    72/72    NaN
# 2011                    72/72    NaN
# 2012                      NaN  74/74
# 2013                      NaN    NaN
# 2014                      NaN    NaN
# 2015                      NaN  74/74
# 2016                      NaN  74/74
# 2017                      NaN  74/74
# ----------------------------------------------- #
# Crop type: Maize Grain (Yellow)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             1998A2
# year
# 1998                     1/72
# 1999                     1/72
# ----------------------------------------------- #
# Crop type: Millet
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             1980A2 1998A2 2011A2
# year
# 1990                    35/57   1/72    NaN
# 1991                    35/57   1/72    NaN
# 1992                    38/57   1/72    NaN
# 1993                    41/57   1/72    NaN
# 1994                      NaN    NaN    NaN
# 1995                      NaN    NaN    NaN
# 1996                      NaN    NaN    NaN
# 1997                    39/57   1/72    NaN
# 1998                      NaN  48/72    NaN
# 1999                      NaN  48/72    NaN
# 2000                      NaN    NaN    NaN
# 2001                      NaN  45/72    NaN
# 2002                      NaN  50/72    NaN
# 2003                      NaN  46/72    NaN
# 2004                      NaN  50/72    NaN
# 2005                      NaN  47/72    NaN
# 2006                      NaN  52/72    NaN
# 2007                      NaN  53/72    NaN
# 2008                      NaN  53/72    NaN
# 2009                      NaN  50/72    NaN
# 2010                      NaN  50/72    NaN
# 2011                      NaN    NaN    NaN
# 2012                      NaN    NaN  47/74
# 2013                      NaN    NaN  54/74
# 2014                      NaN    NaN  50/74
# 2015                      NaN    NaN  51/74
# 2016                      NaN    NaN  46/74
# 2017                      NaN    NaN  48/74
# ----------------------------------------------- #
# Crop type: Millet (Finger)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             1998A2 2011A2
# year
# 2011                    48/72    NaN
# 2012                      NaN    NaN
# 2013                      NaN    NaN
# 2014                      NaN    NaN
# 2015                      NaN   3/74
# 2016                      NaN   3/74
# ----------------------------------------------- #
# Crop type: Rice (Paddy)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             1980A2 1998A2 2011A2
# year
# 1990                    36/57   1/72    NaN
# 1991                    35/57   1/72    NaN
# 1992                    35/57   1/72    NaN
# 1993                    33/57   1/72    NaN
# 1994                      NaN    NaN    NaN
# 1995                      NaN    NaN    NaN
# 1996                      NaN    NaN    NaN
# 1997                    21/57   1/72    NaN
# 1998                      NaN  29/72    NaN
# 1999                      NaN  19/72    NaN
# 2000                      NaN    NaN    NaN
# 2001                      NaN  31/72    NaN
# 2002                      NaN  35/72    NaN
# 2003                      NaN  26/72    NaN
# 2004                      NaN  38/72    NaN
# 2005                      NaN  33/72    NaN
# 2006                      NaN  38/72    NaN
# 2007                      NaN  41/72    NaN
# 2008                      NaN  42/72    NaN
# 2009                      NaN  50/72    NaN
# 2010                      NaN  45/72    NaN
# 2011                      NaN  48/72    NaN
# 2012                      NaN    NaN  47/74
# 2013                      NaN    NaN  47/74
# 2014                      NaN    NaN  46/74
# 2015                      NaN    NaN  48/74
# 2016                      NaN    NaN  42/74
# 2017                      NaN    NaN  44/74
# ----------------------------------------------- #
# Crop type: Sorghum
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             1980A2 1998A2 2011A2
# year
# 1990                    43/57    NaN    NaN
# 1991                    41/57   1/72    NaN
# 1992                    42/57   1/72    NaN
# 1993                    49/57   1/72    NaN
# 1994                      NaN    NaN    NaN
# 1995                      NaN    NaN    NaN
# 1996                      NaN    NaN    NaN
# 1997                    46/57   1/72    NaN
# 1998                      NaN  53/72    NaN
# 1999                      NaN  49/72    NaN
# 2000                      NaN    NaN    NaN
# 2001                      NaN  54/72    NaN
# 2002                      NaN  56/72    NaN
# 2003                      NaN  50/72    NaN
# 2004                      NaN  61/72    NaN
# 2005                      NaN  55/72    NaN
# 2006                      NaN  54/72    NaN
# 2007                      NaN  57/72    NaN
# 2008                      NaN  51/72    NaN
# 2009                      NaN  54/72    NaN
# 2010                      NaN  55/72    NaN
# 2011                      NaN  48/72    NaN
# 2012                      NaN    NaN  49/74
# 2013                      NaN    NaN  49/74
# 2014                      NaN    NaN  48/74
# 2015                      NaN    NaN  55/74
# 2016                      NaN    NaN  52/74
# 2017                      NaN    NaN  51/74
# ----------------------------------------------- #
# Crop type: Wheat Grain
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             1980A2 1998A2 2011A2
# year
# 1990                     4/57    NaN    NaN
# 1991                     5/57    NaN    NaN
# 1992                     5/57    NaN    NaN
# 1993                     6/57    NaN    NaN
# 1994                      NaN    NaN    NaN
# 1995                      NaN    NaN    NaN
# 1996                      NaN    NaN    NaN
# 1997                      NaN    NaN    NaN
# 1998                      NaN   4/72    NaN
# 1999                      NaN   7/72    NaN
# 2000                      NaN    NaN    NaN
# 2001                      NaN    NaN    NaN
# 2002                      NaN    NaN    NaN
# 2003                      NaN   1/72    NaN
# 2004                      NaN  11/72    NaN
# 2005                      NaN  11/72    NaN
# 2006                      NaN   9/72    NaN
# 2007                      NaN  10/72    NaN
# 2008                      NaN  15/72    NaN
# 2009                      NaN  14/72    NaN
# 2010                      NaN    NaN    NaN
# 2011                      NaN  14/72    NaN
# 2012                      NaN    NaN  14/74
# 2013                      NaN    NaN  14/74
# 2014                      NaN    NaN  15/74
# 2015                      NaN    NaN  20/74
# 2016                      NaN    NaN  16/74
# 2017                      NaN    NaN  15/74
# ----------------------------------------------- #
# ./figures/ZM_admin_shapes.png is saved.

# %% [markdown]
# ## Zambia
# Zambia crop seasonal calendar
#
# ![FEWS NET](https://fews.net/sites/default/files/styles/large/public/seasonal-calendar-zambia.png?itok=iCbUXJ29)
#
# ![USDA](https://ipad.fas.usda.gov/rssiws/al/crop_calendar/images/safrica_za_calendar.png)
#
# - comparison of boundaries
# ![image](./figures/ZM_admin_shapes.png)
#
# - In Zambia, basd on the FEWS NET data, there were four times of changes in administrative units: 1980, 1998, 2011, and 2012.
#
# | year	 | Admin1   | # units   | Admin2   | # units   |
# | :---: | :----:  | :----:   | :----:   | :---:  |
# | 1980	 | ZM1980A1 | 9	| ZM1980A2	| 57	|
# | 1990	 | ZM1990A1 | 9	| nan	| 0	|
# | 1998	 | nan | 0	| ZM1998A2	| 72	|
# | 2011	 | ZM2011A1 | 10	| ZM2011A2	| 74	|
# | 2012	 | ZM2012A1 | 10	| ZM2012A2	| 89	|
#
#
# - Here, we use **`ZM2012A2`** to represent all admin-level 2 crop data.
# - The data is all reported as `Annual` for the season
# - Original data have both 'none' and 'all' as production systems, but these are essentially the same, indicating a default produciton system so they have all been changed to 'none' types.

# %%
# Define the latest shapefile ------------------- #
latest_level = 2
shape_latest = ZM_Admin2_2011.copy().to_crs('epsg:4326')
# ----------------------------------------------- #

# Validation of FNIDs and Names ----------------- #
#shape_used['ADMIN2'] = 'None'
#shape_all['ADMIN2'] = 'None'
#shape_latest['ADMIN2'] = 'None'
df = FDW_PD_ValidateFnidName(df, shape_used, shape_latest)
# ----------------------------------------------- #

# FDW Production Data Compiling ----------------- #
area, prod = FDW_PD_Compiling(df, shape_used)
area_all, prod_all = area.copy(), prod.copy()
# - Aggregate grain data by grain type
#FlagGrainType = True
#[area, prod, area_all, prod_all] = FDW_PD_GrainTypeAgg([area, prod, area_all, prod_all], product_category)
mdx_pss = area.columns.droplevel([0,1]).unique()
# ----------------------------------------------- #
# Out:
# ZM1998A21208:	"Mpulungu" (FDW) is changed to "Chinsali" (shapefile).

# %%
# Link admin boundaries ------------------------- #
link_1998, over_1998 = FDW_PD_CreateAdminLink(ZM_Admin2_1998, ZM_Admin2_2011, 'ADMIN2', 'ADMIN2', prod, epsg)
link_1980, over_1980 = FDW_PD_CreateAdminLink(ZM_Admin2_1980, ZM_Admin2_2011, 'ADMIN2', 'ADMIN2', prod, epsg)
# Crop specific ratios
link_ratio_1998 = FDW_PD_RatioAdminLink(link_1998, prod, over_1998, mdx_pss)
link_ratio_1980 = FDW_PD_RatioAdminLink(link_1980, prod, over_1980, mdx_pss)

# Merge link_ratio
assert link_ratio_1998.keys() == link_ratio_1980.keys()

link_merged = [link_ratio_1980, link_ratio_1998]
fnids_new = list(link_merged[0].keys())
link_ratio = dict()
for fnid in fnids_new:
    container = []
    for link in link_merged:
        container.append(link[fnid])
    link_ratio[fnid] = pd.concat(container, axis=1)
# Add current unit to link_ratio
for fnid_new in link_ratio.keys():
    link_ratio[fnid_new][fnid_new] = 1.0
    link_ratio[fnid_new] = link_ratio[fnid_new].sort_index(axis=1, ascending=False)
# Connect data with AdminLink
area_new, prod_new = FDW_PD_ConnectAdminLink(link_ratio, area, prod, validation=False)
# ----------------------------------------------- #

# %%
# Manual correction ----------------------------- #
crop_new = prod_new/area_new

# Complete long format DataFrame ---------------- #
df_area = area_new.T.stack().rename('value').reset_index()
df_area['indicator'] = 'area'
df_prod = prod_new.T.stack().rename('value').reset_index()
df_prod['indicator'] = 'production'
df_yield = (prod_new/area_new).T.stack().rename('value').reset_index()
df_yield['indicator'] = 'yield'
stack = pd.concat([df_area, df_prod, df_yield], axis=0)
# Add "growing year"
cols = ['season_name','product','crop_production_system','growing_month','harvest_year','harvest_month','growing_year']
season_table = df[cols].drop_duplicates()
stack = stack.merge(season_table, on=cols[:-1])
# Add country and admin names
stack = stack.merge(df[['fnid','country','country_code','admin_1','admin_2']].drop_duplicates(), on='fnid', how='inner')
names = [
    'fnid','country','country_code','admin_1','admin_2','name',
    'product','season_name','growing_year','growing_month','harvest_year','harvest_month',
    'crop_production_system','indicator','value'
]
stack_gscd = stack[names]
stack_gscd['gscd_code'] = 'calibrated'
# ----------------------------------------------- #

# Reported FDW data ----------------------------- #
stack_fdw = df[names]
stack_fdw['indicator'] = stack_fdw['indicator'].replace({'Area Harvested':'area','Quantity Produced':'production','Yield':'yield'})
stack_fdw['gscd_code'] = 'reported'
# ----------------------------------------------- #

# Final Processing ------------------------------ #
stack = pd.concat([stack_fdw,stack_gscd], axis=0).reset_index(drop=True)
# No concerns found for grain types
stack['product'] = stack['product'].replace(product_category)

# No calibration of Growing and Harvest year and season is needed
cs = {
    'Annual': {'growing_month':{'04-01':'04-01'},'harvest_month':{'07-01':'07-01'}},
}
cy = {}
stack, df, link_ratio = FDW_PD_CaliSeasonYear(stack, df, link_ratio, cs, cy)
stack.loc[stack['admin_1'].isna(), 'admin_1'] = 'none'
stack.loc[stack['admin_2'].isna(), 'admin_2'] = 'none'
# # ----------------------------------------------- #

# Save data
save_hdf('./data/crop/adm_crop_production_ZM.hdf', stack)
save_hdf('./data/crop/adm_crop_production_ZM_raw.hdf', df)
save_npz('./data/crop/adm_crop_production_ZM_ratio.npz', link_ratio)
# Out:
# ./data/crop/adm_crop_production_ZM.hdf is saved.
# ./data/crop/adm_crop_production_ZM_raw.hdf is saved.
# ./data/crop/adm_crop_production_ZM_ratio.npz is saved.

# %% [markdown]
# ## Visualization of production data

# %%
# Bar chart of national grain production
country_iso, country_name = 'ZM', 'Zambia'
df = pd.read_hdf('./data/crop/adm_crop_production_%s.hdf' % country_iso)
df = df[df['gscd_code']=='calibrated']; df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_order = ['Wheat', 'Sorghum', 'Millet','Barley',  'Rice','Maize']
for season_name in ['Annual']:
    footnote = 'National grain production in %s - %s' % (country_name, season_name)
    fn_save = './figures/%s_bar_natgrainprod_%s.png' % (country_iso, season_name)
    sub = df[df['season_name'] == season_name]
    fig = PlotBarProduction(sub, year, product_order, footnote, fn_save)
    fig.show()
# Out:
# ./figures/ZM_bar_natgrainprod_Annual.png is saved.
# <div>                            <div id="49497b58-80f9-45a1-96fc-fb65da36c8c9" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49497b58-80f9-45a1-96fc-fb65da36c8c9")) {                    Plotly.newPlot(                        "49497b58-80f9-45a1-96fc-fb65da36c8c9",                        [{"alignmentgroup":"True","hovertemplate":"product=Wheat<br>season_name=Annual<br>type=orig_unit<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Wheat","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Wheat","offsetgroup":"Wheat","orientation":"v","showlegend":true,"textposition":"auto","x":[1990,1991,1992,1993,1998,1999,2003,2004,2005,2006,2007,2008,2009,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x2","y":[78.0,163.0,82.0,1588.0,3617.91,34407.08,24523.95,82858.0,136832.82,53479.0,115842.87823762,63880.0,195456.36,237332.39139186,253522.14868543,273583.66959454,201504.13209169998,208498.88778778,159398.68683315002,193713.15433321998],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product=Wheat<br>season_name=Annual<br>type=percent<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Wheat","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Wheat","offsetgroup":"Wheat","orientation":"v","showlegend":false,"textposition":"auto","x":[1990,1991,1992,1993,1998,1999,2003,2004,2005,2006,2007,2008,2009,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[0.006843588040566685,0.01429889784446308,0.015240530890883374,0.1236868976786898,0.5331118794171013,3.9162209207313947,2.0192995499646984,6.1845342375716745,13.625163185175476,3.579105777324555,7.865429128245344,5.291632486017723,9.48350432836663,7.438526633625477,8.348076823365345,9.915732399337989,5.804500003771589,8.146109465079029,5.7094132867569956,5.30388294645093],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product=Sorghum<br>season_name=Annual<br>type=orig_unit<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Sorghum","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Sorghum","offsetgroup":"Sorghum","orientation":"v","showlegend":true,"textposition":"auto","x":[1990,1991,1992,1993,1997,1998,1999,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x2","y":[20355.0,24487.0,13958.0,34041.0,29281.55,24571.07,23347.02,24382.24,16452.0,19977.28,24272.59867,17244.31,19473.0,12729.69690184,9988.0,21700.55427,23988.928848180003,17765.35098776,15138.82508882,14923.63260757,11481.41454461,7876.266071190001,13904.03013359,17255.708027599998],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product=Sorghum<br>season_name=Annual<br>type=percent<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Sorghum","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Sorghum","offsetgroup":"Sorghum","orientation":"v","showlegend":false,"textposition":"auto","x":[1990,1991,1992,1993,1997,1998,1999,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[1.7859132636632673,2.1480804387568555,2.5942357338408555,2.6514015641563473,2.871806199277618,3.620634373710003,2.657362617250121,3.483032157662972,2.541367506580492,1.6449272043662935,1.8117106074181335,1.7171065959596044,1.3032391555908125,0.8643132001614182,0.8273767262107861,1.0529066454910958,0.9675826407634252,0.5568057343675754,0.4984971747528549,0.5408902789483307,0.33073203053307015,0.30772790336084527,0.4980207551350982,0.47246278060750585],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product=Millet<br>season_name=Annual<br>type=orig_unit<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Millet","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Millet","offsetgrou ...

# %%
# Lineplot of Production-Area-Yield (PAY) time-series
country_iso, country_name = 'ZM', 'Zambia'
df = pd.read_hdf('./data/crop/adm_crop_production_%s.hdf' % country_iso)
df = df[df['gscd_code']=='calibrated']; df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_season = [
    ['Barley', 'Annual'],
    ['Maize', 'Annual'],
    ['Millet', 'Annual'],
    ['Rice', 'Annual'],
    ['Sorghum', 'Annual'],
    ['Wheat', 'Annual'],
]
for product_name, season_name in product_season:
    footnote = 'Production-Area-Yield (PAY) time-series of %s - %s - %s' % (country_iso, product_name, season_name)
    fn_save = './figures/%s_line_pay_%s_%s.png' % (country_iso, product_name, season_name)
    sub = df[(df['product'] == product_name) & (df['season_name'] == season_name)]
    fig = PlotLinePAY(sub, year, footnote, fn_save)
    fig.show()
# Out:
# ./figures/ZM_line_pay_Barley_Annual.png is saved.
# <div>                            <div id="dcbbd912-9710-4e84-a5f4-f83324013535" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dcbbd912-9710-4e84-a5f4-f83324013535")) {                    Plotly.newPlot(                        "dcbbd912-9710-4e84-a5f4-f83324013535",                        [{"hovertemplate":"fnid=ZM2011A20101<br>indicator=production<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ZM2011A20101","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"ZM2011A20101","orientation":"v","showlegend":true,"x":[2011,2012,2013,2014,2015,2016],"xaxis":"

df = pd.read_hdf('./data/crop/adm_crop_production_%s.hdf' % country_iso)
df = df[df['gscd_code']=='calibrated']; df['year'] = df['harvest_year']
link_ratio = load_npz('./data/crop/adm_crop_production_%s_ratio.npz' % country_iso)
year_all = np.arange(df['year'].min(), df['year'].max()+1)
product_season = [
    ['Barley', 'Annual'],
    ['Maize', 'Annual'],
    ['Millet', 'Annual'],
    ['Rice', 'Annual'],
    ['Sorghum', 'Annual'],
    ['Wheat', 'Annual'],
]
for product_name, season_name in product_season:
    sub = df[
        (df['product'] == product_name) &
        (df['season_name'] == season_name)
    ]
    for fnid in sub['fnid'].unique():
        sub_fps = sub[sub['fnid'] == fnid]
        fn_save = './figures/crop_calibrated/%s_%s_%s_%s.png' % (country_iso, product_name, season_name, fnid)
        fig = PlotLineCropTS(sub_fps, fnid, product_name, season_name, link_ratio, year_all, fn_save)
# Out:
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20101.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20105.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20110.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20206.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20208.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20210.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20304.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20506.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20511.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20512.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20808.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20902.png is saved.
# ./figures/crop_calibrated/ZM_Barley_Annual_ZM2011A20916.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20101.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20105.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20106.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20110.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20111.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20113.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20201.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20202.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20203.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20205.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20206.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20207.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20208.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20209.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20210.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20302.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20304.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20305.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20306.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20307.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20401.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20406.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20407.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20410.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20415.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20505.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20506.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20511.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20512.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20601.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20603.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20604.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20605.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20606.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20701.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20703.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20704.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20707.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20801.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20802.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20804.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20806.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20808.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20810.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20811.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20902.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20903.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20905.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20906.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20909.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20910.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20916.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20917.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A21001.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A21007.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A21012.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A21014.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A21018.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A21019.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A21020.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20911.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20908.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20702.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20714.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20912.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20414.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20204.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20404.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20814.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20313.png is saved.
# ./figures/crop_calibrated/ZM_Maize_Annual_ZM2011A20312.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20101.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20105.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20106.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20110.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20111.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20113.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20201.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20202.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20203.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20205.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20206.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20207.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20208.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20209.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20210.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20302.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20304.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20305.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20306.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20307.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20401.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20406.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20407.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20410.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20415.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20505.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20506.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20511.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20512.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20601.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20603.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20604.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20605.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20606.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20701.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20703.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20704.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20707.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20801.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20804.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20806.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20808.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20810.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20811.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20902.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20903.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20905.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20906.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20909.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20910.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20916.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20917.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A21001.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A21007.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A21012.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A21014.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A21018.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A21019.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A21020.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20911.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20908.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20702.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20714.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20912.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20414.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20204.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20404.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20814.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20313.png is saved.
# ./figures/crop_calibrated/ZM_Millet_Annual_ZM2011A20312.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20101.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20105.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20106.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20110.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20111.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20113.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20201.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20202.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20203.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20205.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20206.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20207.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20208.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20209.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20210.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20302.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20304.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20305.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20306.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20307.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20401.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20406.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20407.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20410.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20415.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20505.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20506.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20511.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20512.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20601.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20603.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20604.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20605.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20606.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20701.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20703.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20704.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20707.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20801.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20802.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20804.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20806.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20808.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20810.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20811.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20902.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20903.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20905.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20909.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20916.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A21001.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A21007.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A21012.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A21014.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A21018.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A21019.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A21020.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20908.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20702.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20714.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20912.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20414.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20204.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20404.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20814.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20313.png is saved.
# ./figures/crop_calibrated/ZM_Rice_Annual_ZM2011A20312.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20101.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20105.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20106.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20110.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20111.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20113.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20201.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20202.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20203.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20205.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20206.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20207.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20208.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20209.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20210.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20302.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20304.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20305.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20306.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20307.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20401.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20406.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20407.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20410.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20415.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20505.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20506.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20511.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20512.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20601.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20603.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20604.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20605.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20606.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20701.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20703.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20704.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20707.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20801.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20802.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20804.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20806.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20808.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20810.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20811.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20902.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20903.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20905.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20906.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20909.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20910.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20916.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20917.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A21001.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A21007.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A21012.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A21014.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A21018.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A21019.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A21020.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20911.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20908.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20702.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20714.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20912.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20414.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20204.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20404.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20814.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20313.png is saved.
# ./figures/crop_calibrated/ZM_Sorghum_Annual_ZM2011A20312.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20101.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20105.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20106.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20110.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20111.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20201.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20202.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20203.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20205.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20206.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20207.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20208.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20209.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20210.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20302.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20305.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20307.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20506.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20511.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20512.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20605.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20703.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20802.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20808.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20902.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20905.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20906.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20916.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20917.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A21012.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20908.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20912.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20204.png is saved.
# ./figures/crop_calibrated/ZM_Wheat_Annual_ZM2011A20313.png is saved.
